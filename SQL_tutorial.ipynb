# %% [markdown]
# ### Importing data to a SQL database
#
# Once you have a database up and running, one of the tasks you'll do most often is import data into a new or existing table. There are many different ways to do this. Here we illustrate how you can use some simple Python packages to connect to the database and import the Seattle Crimes csv file.

# %% [markdown]
# #### import the libraries
# We will use [pandas](pandas.pydata.org) which is a fantastic data analysis toolkit that happens to have some very simple methods for moving data to and from a database. The datbase connections are handled through pandas using [sqlalchemy](www.sqlalchemy.org).

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# #### connecting to the database
# Our next step is to pass some database connection information to pandas/sqlalchemy so that we can establish a connection. We create a database "engine" object that is then used in subsequent operations as a portal to/from the database.

# %%
host = 'dssg2016.cel0foggtnsk.us-east-1.rds.amazonaws.com'
user = 'dssg_student'
password = 'dssg2016'
port = '5432'
dbname = 'dssg2016'

#instantiate engine to interface with database
engine = create_engine('postgresql://' + user + ':' + password + '@' + host + ':' + port + '/' + dbname)

# %% [markdown]
# #### issue a SQL command to test the connection

# %%
crimesData = pd.read_csv('SeattleCrimeIncidents.csv')

# %%
crimesData
# Out:
#        RMS CDW ID  General Offense Number Offense Code  \
# 0            6943               201531478            X
# 1            6947               201531582         5015
# 2            8069               201533387         5015
# 3            8075               201531544            X
# 4            8079               201529694         5707
# 5            8080               201530599            X
# 6            8082               201530221         5707
# 7            8083               201530778         4812
# 8            8628               201533448         5015
# 9           10174               201532410         5707
# 10          10175               201529878         5707
# 11          10968               201533421         2316
# 12          10981               201530765         5404
# 13          10984               201530047         1316
# 14          10989               201530618            X
# 15          10991               201530459         2202
# 16          10995               201530637         1305
# 17          10996               201530681         1316
# 18          10998               201529925            X
# 19          11006              2015900577         2399
# 20          11007              2015900576         2610
# 21          11008              2015900574         2610
# 22          11011               201530327         5015
# 23          11012               201529787         2204
# 24          11013               201529931         2203
# 25          11014               201530219         5707
# 26          11020               201529876         5015
# 27          11021               201529805         1313
# 28          11028               201530474         1203
# 29          11033               201530019         5015
# ...           ...                     ...          ...
# 30784     1125320               201528742         2305
# 30785     1125321               201528944         2299
# 30786     1125322               201529510         5212
# 30787     1125323               201529557         3512
# 30788     1125324               201529328         2303
# 30789     1125325               201529675         2305
# 30790     1125326                20151312         2299
# 30791     1125327               201529805         1313
# 30792     1125328               201529553         2399
# 30793     1125329               201530031         1316
# 30794     1125330               201530219         5707
# 30795     1125331               201529272         2202
# 30796     1125332               201529567         2204
# 30797     1125333               201530194         1316
# 30798     1125334               201530509         5707
# 30799     1125335               201530236         2204
# 30800     1125336               201530047         1316
# 30801     1125337               201529925            X
# 30802     1125338               201530765         5404
# 30803     1125339               201530708         1316
# 30804     1125340               201519567         2699
# 30805     1125341               201530888         1203
# 30806     1125342               201530768         1204
# 30807     1125343               201530681         1316
# 30808     1125344               201530710         5404
# 30809     1125345               201530637         1305
# 30810     1125346               201529798         5015
# 30811     1125347               201530077         2202
# 30812     1125348               201530367         2202
# 30813     1125349               201530459         2202
#
#        Offense Code Extension                 Offense Type  \
# 0                          92                BIAS INCIDENT
# 1                           2          WARRARR-MISDEMEANOR
# 2                           1               WARRARR-FELONY
# 3                          48                PROPERTY LOST
# 4                           0                     TRESPASS
# 5                          48                PROPERTY LOST
# 6                           0                     TRESPASS
# 7                           0                 FALSE REPORT
# 8                           1               WARRARR-FELONY
# 9                           0                     TRESPASS
# 10                          0                     TRESPASS
# 11                          0                   THEFT-MAIL
# 12                          0                   DUI-LIQUOR
# 13                          4                THREATS-OTHER
# 14                         21              DISTURBANCE-OTH
# 15                          0           BURGLARY-FORCE-RES
# 16                          0             ASSLT-AGG-WEAPON
# 17                          4                THREATS-OTHER
# 18                          6                   ANIMAL-OTH
# 19                          3                    THEFT-OTH
# 20                          0         FRAUD-IDENTITY THEFT
# 21                          0         FRAUD-IDENTITY THEFT
# 22                          1               WARRARR-FELONY
# 23                          0         BURGLARY-NOFORCE-RES
# 24                          0        BURGLARY-FORCE-NONRES
# 25                          0                     TRESPASS
# 26                          1               WARRARR-FELONY
# 27                          0                 ASSLT-NONAGG
# 28                          3   ROBBERY-BUSINESS-BODYFORCE
# 29                          1               WARRARR-FELONY
# ...                       ...                          ...
# 30784                       0               THEFT-CARPROWL
# 30785                       2  BURGLARY-SECURE PARKING-RES
# 30786                       0            WEAPON-POSSESSION
# 30787                       0          NARC-POSSESS-HEROIN
# 30788                       0               THEFT-SHOPLIFT
# 30789                       0               THEFT-CARPROWL
# 30790                       2  BURGLARY-SECURE PARKING-RES
# 30791                       0                 ASSLT-NONAGG
# 30792                       1                THEFT-BICYCLE
# 30793                       3                 THREATS-KILL
# 30794                       0                     TRESPASS
# 30795                       0           BURGLARY-FORCE-RES
# 30796                       0         BURGLARY-NOFORCE-RES
# 30797                       3                 THREATS-KILL
# 30798                       0                     TRESPASS
# 30799                       0         BURGLARY-NOFORCE-RES
# 30800                       4                THREATS-OTHER
# 30801                       6                   ANIMAL-OTH
# 30802                       0                   DUI-LIQUOR
# 30803                       3                 THREATS-KILL
# 30804                       1                  FRAUD-OTHER
# 30805                       3   ROBBERY-BUSINESS-BODYFORCE
# 30806                       0           ROBBERY-STREET-GUN
# 30807                       4                THREATS-OTHER
# 30808                       0                   DUI-LIQUOR
# 30809                       0             ASSLT-AGG-WEAPON
# 30810                       3             WARRANT-FUGITIVE
# 30811                       0           BURGLARY-FORCE-RES
# 30812                       0           BURGLARY-FORCE-RES
# 30813                       0           BURGLARY-FORCE-RES
#
#       Summary Offense Code Summarized Offense Description  \
# 0                        X                  BIAS INCIDENT
# 1                     5000                 WARRANT ARREST
# 2                     5000                 WARRANT ARREST
# 3                        X                  LOST PROPERTY
# 4                     5700                       TRESPASS
# 5                        X                  LOST PROPERTY
# 6                     5700                       TRESPASS
# 7                     4800                   FALSE REPORT
# 8                     5000                 WARRANT ARREST
# 9                     5700                       TRESPASS
# 10                    5700                       TRESPASS
# 11                    2300                     MAIL THEFT
# 12                    5400                            DUI
# 13                    1300                        THREATS
# 14                       X                    DISTURBANCE
# 15                    2200                       BURGLARY
# 16                    1300                        ASSAULT
# 17                    1300                        THREATS
# 18                       X               ANIMAL COMPLAINT
# 19                    2300                 OTHER PROPERTY
# 20                    2600                          FRAUD
# 21                    2600                          FRAUD
# 22                    5000                 WARRANT ARREST
# 23                    2200                       BURGLARY
# 24                    2200                       BURGLARY
# 25                    5700                       TRESPASS
# 26                    5000                 WARRANT ARREST
# 27                    1300                        ASSAULT
# 28                    1200                        ROBBERY
# 29                    5000                 WARRANT ARREST
# ...                    ...                            ...
# 30784                 2300                      CAR PROWL
# 30785                 2299    BURGLARY-SECURE PARKING-RES
# 30786                 5200                         WEAPON
# 30787                 3500                      NARCOTICS
# 30788                 2300                    SHOPLIFTING
# 30789                 2300                      CAR PROWL
# 30790                 2299    BURGLARY-SECURE PARKING-RES
# 30791                 1300                        ASSAULT
# 30792                 2300                     BIKE THEFT
# 30793                 1300                        THREATS
# 30794                 5700                       TRESPASS
# 30795                 2200                       BURGLARY
# 30796                 2200                       BURGLARY
# 30797                 1300                        THREATS
# 30798                 5700                       TRESPASS
# 30799                 2200                       BURGLARY
# 30800                 1300                        THREATS
# 30801                    X               ANIMAL COMPLAINT
# 30802                 5400                            DUI
# 30803                 1300                        THREATS
# 30804                 2600                          FRAUD
# 30805                 1200                        ROBBERY
# 30806                 1200                        ROBBERY
# 30807                 1300                        THREATS
# 30808                 5400                            DUI
# 30809                 1300                        ASSAULT
# 30810                 5000                 WARRANT ARREST
# 30811                 2200                       BURGLARY
# 30812                 2200                       BURGLARY
# 30813                 2200                       BURGLARY
#
#                 Date Reported Occurred Date or Date Range Start  \
# 0      01/28/2015 09:30:00 AM            01/28/2015 08:45:00 AM
# 1      01/28/2015 11:05:00 AM            01/28/2015 11:05:00 AM
# 2      01/29/2015 07:57:00 PM            01/29/2015 07:57:00 PM
# 3      01/28/2015 03:17:00 PM            01/24/2015 12:00:00 AM
# 4      01/27/2015 04:25:00 AM            01/27/2015 04:25:00 AM
# 5      01/27/2015 09:05:00 PM            01/26/2015 11:00:00 AM
# 6      01/27/2015 07:57:00 PM            01/27/2015 07:57:00 PM
# 7      01/27/2015 10:36:00 PM            12/27/2014 12:20:00 PM
# 8      01/29/2015 10:36:00 PM            01/29/2015 09:08:00 PM
# 9      01/29/2015 02:04:00 AM            01/29/2015 01:32:00 AM
# 10     01/27/2015 09:11:00 AM            01/27/2015 09:11:00 AM
# 11     01/29/2015 08:28:00 PM            01/29/2015 08:28:00 PM
# 12     01/28/2015 02:08:00 AM            01/27/2015 10:20:00 PM
# 13     01/27/2015 11:42:00 AM            01/27/2015 08:30:00 AM
# 14     01/27/2015 07:58:00 PM            01/27/2015 07:36:00 PM
# 15     01/27/2015 07:04:00 PM            01/27/2015 07:04:00 PM
# 16     01/27/2015 07:56:00 PM            01/27/2015 07:56:00 PM
# 17     01/27/2015 08:45:00 PM            01/27/2015 08:45:00 PM
# 18     01/27/2015 09:41:00 AM            01/27/2015 09:41:00 AM
# 19     01/27/2015 10:53:00 AM            01/03/2015 07:55:00 PM
# 20     01/27/2015 10:50:00 AM            01/15/2015 10:45:00 AM
# 21     01/27/2015 09:37:00 AM            12/27/2012 09:30:00 AM
# 22     01/27/2015 04:39:00 PM            01/27/2015 03:29:00 PM
# 23     01/27/2015 07:19:00 AM            01/27/2015 01:00:00 AM
# 24     01/27/2015 09:52:00 AM            01/27/2015 05:00:00 AM
# 25     01/27/2015 02:06:00 PM            01/27/2015 02:06:00 PM
# 26     01/27/2015 10:50:00 AM            01/27/2015 09:05:00 AM
# 27     01/27/2015 07:32:00 AM            01/27/2015 07:32:00 AM
# 28     01/27/2015 05:54:00 PM            01/27/2015 05:54:00 PM
# 29     01/27/2015 11:20:00 AM            01/27/2015 11:20:00 AM
# ...                       ...                               ...
# 30784  01/26/2015 11:17:00 AM            01/24/2015 10:30:00 AM
# 30785  01/26/2015 03:56:00 PM            01/26/2015 01:31:00 PM
# 30786  01/26/2015 10:12:00 PM            01/26/2015 10:12:00 PM
# 30787  01/27/2015 01:10:00 AM            01/26/2015 11:33:00 PM
# 30788  01/26/2015 06:18:00 PM            01/26/2015 06:18:00 PM
# 30789  01/27/2015 05:09:00 AM            01/27/2015 03:55:00 AM
# 30790  01/02/2015 10:00:00 AM            11/02/2014 12:01:00 AM
# 30791  01/27/2015 07:32:00 AM            01/27/2015 07:32:00 AM
# 30792  01/27/2015 12:04:00 AM            01/26/2015 11:28:00 PM
# 30793  01/27/2015 11:30:00 AM            01/27/2015 11:30:00 AM
# 30794  01/27/2015 02:06:00 PM            01/27/2015 02:06:00 PM
# 30795  01/26/2015 05:31:00 PM            01/26/2015 05:31:00 PM
# 30796  01/26/2015 11:57:00 PM            01/26/2015 11:57:00 PM
# 30797  01/27/2015 03:46:00 PM            01/27/2015 01:58:00 PM
# 30798  01/27/2015 05:48:00 PM            01/27/2015 05:48:00 PM
# 30799  01/27/2015 03:24:00 PM            01/23/2015 08:00:00 PM
# 30800  01/27/2015 11:42:00 AM            01/27/2015 08:30:00 AM
# 30801  01/27/2015 09:41:00 AM            01/27/2015 09:41:00 AM
# 30802  01/28/2015 02:08:00 AM            01/27/2015 10:20:00 PM
# 30803  01/27/2015 09:10:00 PM            01/27/2015 08:10:00 PM
# 30804  01/21/2015 07:38:00 AM            01/18/2015 12:15:00 PM
# 30805  01/28/2015 02:10:00 AM            01/28/2015 02:10:00 AM
# 30806  01/28/2015 12:05:00 AM            01/27/2015 10:20:00 PM
# 30807  01/27/2015 08:45:00 PM            01/27/2015 08:45:00 PM
# 30808  01/28/2015 02:36:00 AM            01/27/2015 09:13:00 PM
# 30809  01/27/2015 07:56:00 PM            01/27/2015 07:56:00 PM
# 30810  01/27/2015 09:34:00 AM            01/27/2015 07:00:00 AM
# 30811  01/27/2015 12:15:00 PM            01/27/2015 11:45:00 AM
# 30812  01/27/2015 03:52:00 PM            01/27/2015 03:25:00 PM
# 30813  01/27/2015 07:04:00 PM            01/27/2015 07:04:00 PM
#
#       Occurred Date Range End           Hundred Block Location  \
# 0      01/28/2015 08:50:00 AM              16XX BLOCK OF 11 AV
# 1                         NaN      2 AV ET S / S WASHINGTON ST
# 2                         NaN      12XX BLOCK OF S DEARBORN ST
# 3      01/24/2015 01:00:00 AM          11XX BLOCK OF E PIKE ST
# 4                         NaN            12XX BLOCK OF 15 AV E
# 5      01/27/2015 06:00:00 PM       4XX BLOCK OF UNIVERSITY ST
# 6                         NaN             2XX BLOCK OF 23 AV E
# 7                         NaN            77XX BLOCK OF 46 AV S
# 8                         NaN          123XX BLOCK OF 35 AV NE
# 9                         NaN          123XX BLOCK OF 15 AV NE
# 10                        NaN      53XX BLOCK OF TALLMAN AV NW
# 11                        NaN            60XX BLOCK OF 33 AV S
# 12                        NaN         19XX BLOCK OF WESTERN AV
# 13                        NaN            8XX BLOCK OF NW 67 ST
# 14     01/27/2015 07:58:00 PM          6XX BLOCK OF BROADWAY E
# 15                        NaN             80XX BLOCK OF 8 AV S
# 16                        NaN                5XX BLOCK OF 3 AV
# 17                        NaN       S GRAHAM ST / RAINIER AV S
# 18                        NaN  8XX BLOCK OF NW CARKEEK PARK RD
# 19     01/03/2015 07:55:00 PM         12XX BLOCK OF MADISON ST
# 20     01/27/2015 10:45:00 AM        34XX BLOCK OF W BLAINE ST
# 21     01/27/2015 09:30:00 AM        34XX BLOCK OF W BLAINE ST
# 22                        NaN        92XX BLOCK OF OLSON PL SW
# 23     01/27/2015 07:00:00 AM          6XX BLOCK OF E OLIVE ST
# 24     01/27/2015 05:45:00 AM      52XX BLOCK OF BALLARD AV NW
# 25                        NaN         12XX BLOCK OF MADISON ST
# 26                        NaN               29XX BLOCK OF 1 AV
# 27                        NaN              3XX BLOCK OF 2 AV S
# 28                        NaN           14XX BLOCK OF BROADWAY
# 29                        NaN                2 AV / STEWART ST
# ...                       ...                              ...
# 30784  01/24/2015 04:00:00 PM        S ATLANTIC ST / UTAH AV S
# 30785  01/26/2015 01:31:00 PM      20XX BLOCK OF EASTLAKE AV E
# 30786                     NaN                   3 AV / PIKE ST
# 30787                     NaN               15XX BLOCK OF 2 AV
# 30788                     NaN                   3 AV / PIKE ST
# 30789                     NaN        8XX BLOCK OF S FIDALGO ST
# 30790  11/30/2014 11:58:00 PM   47XX BLOCK OF UNIVERSITY WY NE
# 30791                     NaN              3XX BLOCK OF 2 AV S
# 30792                     NaN       39XX BLOCK OF S OTHELLO ST
# 30793                     NaN            4XX BLOCK OF BROADWAY
# 30794                     NaN         12XX BLOCK OF MADISON ST
# 30795                     NaN            15XX BLOCK OF 29 AV S
# 30796                     NaN            77XX BLOCK OF 2 AV NE
# 30797                     NaN          16XX BLOCK OF S LANE ST
# 30798                     NaN  73XX BLOCK OF E GREEN LAKE DR N
# 30799  01/25/2015 05:00:00 PM             4XX BLOCK OF 10 AV E
# 30800                     NaN            8XX BLOCK OF NW 67 ST
# 30801                     NaN  8XX BLOCK OF NW CARKEEK PARK RD
# 30802                     NaN         19XX BLOCK OF WESTERN AV
# 30803                     NaN                   2 AV / PINE ST
# 30804                     NaN             4 AV / UNIVERSITY ST
# 30805                     NaN           92XX BLOCK OF 35 AV SW
# 30806                     NaN       72XX BLOCK OF RAINIER AV S
# 30807                     NaN       S GRAHAM ST / RAINIER AV S
# 30808                     NaN           4 AV S / S MICHIGAN ST
# 30809                     NaN                5XX BLOCK OF 3 AV
# 30810                     NaN           51 AV S / RAINIER AV S
# 30811  01/27/2015 12:10:00 PM            15XX BLOCK OF 17 AV S
# 30812  01/27/2015 03:45:00 PM           125XX BLOCK OF 3 AV NW
# 30813                     NaN             80XX BLOCK OF 8 AV S
#
#       District/Sector Zone/Beat  Census Tract 2000   Longitude   Latitude  \
# 0                   E        E2          7500.5009 -122.318169  47.615838
# 1                   K        K2          9200.2002 -122.331216  47.600877
# 2                   G        G3          9100.1024 -122.317569  47.595821
# 3                   E        E2          7500.4018 -122.317488  47.614099
# 4                   C        C1          6500.1032 -122.312508  47.631488
# 5                   M        M3          8100.2021 -122.334312  47.608460
# 6                   C        C2          7600.2011 -122.302490  47.620791
# 7                   S        S2         11101.3008 -122.275317  47.533010
# 8                   L        L3           800.1005 -122.291138  47.718291
# 9                   L        L1           700.3004 -122.312648  47.718508
# 10                  B        B1          4700.4020 -122.380892  47.667964
# 11                  S        S1         10401.3001 -122.290297  47.546474
# 12                  M        M1          8100.3011 -122.342880  47.609813
# 13                  J        J2          3300.1002 -122.367115  47.677750
# 14                  E        E1          7401.2000 -122.320937  47.624662
# 15                  F        F3         11200.2042 -122.322842  47.530883
# 16                  K        K2          8100.2043 -122.331082  47.602412
# 17                  S        S2         11101.4000 -122.275992  47.546025
# 18                  N        N1          1400.4000 -122.366805  47.711246
# 19                  E        E3          8400.2015 -122.323473  47.610035
# 20                  Q        Q1          5600.3012 -122.402362  47.634814
# 21                  Q        Q1          5600.3012 -122.402362  47.634814
# 22                  F        F3         26500.1002 -122.337348  47.520472
# 23                  E        E1          7402.2003 -122.323962  47.616356
# 24                  B        B1          4700.4016 -122.382666  47.665957
# 25                  E        E3          8400.2015 -122.323473  47.610035
# 26                  D        D1          8001.1002 -122.353169  47.617309
# 27                  K        K3          9200.2028 -122.330807  47.600464
# 28                  E        E2          8400.1008 -122.320771  47.613520
# 29                  M        M1          8002.1002 -122.340456  47.610964
# ...               ...       ...                ...         ...        ...
# 30784               K        K3          9300.2015 -122.335119  47.590310
# 30785               D        D2          6600.3009 -122.325897  47.637507
# 30786               K        K1          8100.2010 -122.337793  47.609748
# 30787               K        K1          8100.2004 -122.339358  47.609782
# 30788               K        K1          8100.2010 -122.337793  47.609748
# 30789               O        O3         10900.2062 -122.322836  47.549476
# 30790               U        U3          5301.2000 -122.313088  47.663996
# 30791               K        K2          9200.2021 -122.330807  47.600464
# 30792               S        S1         11000.1011 -122.282345  47.537044
# 30793               E        E3          8500.2013 -122.320749  47.605720
# 30794               D        D3          8400.1027 -122.323473  47.610035
# 30795               R        R1          9500.6020 -122.294882  47.588870
# 30796               J        J1          2700.2008 -122.326975  47.685923
# 30797               G        G2          9000.2008 -122.310281  47.596648
# 30798               J        J1          3600.2008 -122.327083  47.681399
# 30799               C        C2          7500.3006 -122.319915  47.622554
# 30800               B        B3          3300.1001 -122.367115  47.677750
# 30801               B        B1          1400.5000 -122.366805  47.711246
# 30802               M        M3          8100.1012 -122.342880  47.609813
# 30803               M        M3          8100.2004 -122.339815  47.610276
# 30804               K        K1          8100.2015 -122.334870  47.608227
# 30805               F        F2         11400.5009 -122.376792  47.520174
# 30806               S        S1         11101.1005 -122.270507  47.537960
# 30807               S        S1         11101.5000 -122.275992  47.546025
# 30808               O        O2         10900.2086 -122.329591  47.545334
# 30809               K        K2          8100.2035 -122.331082  47.602412
# 30810               S        S2         11800.6015 -122.269722  47.520146
# 30811               O        O1          9400.5007 -122.310545  47.589211
# 30812               B        B1           402.5007 -122.360956  47.720542
# 30813               F        F3         11200.2026 -122.322842  47.530883
#
#                              Location  Month  Year
# 0      (47.615838397, -122.318168851)      1  2015
# 1      (47.600877085, -122.331216231)      1  2015
# 2      (47.595820978, -122.317569142)      1  2015
# 3      (47.614099103, -122.317488403)      1  2015
# 4      (47.631488245, -122.312507873)      1  2015
# 5       (47.608460263, -122.33431158)      1  2015
# 6      (47.620791189, -122.302490426)      1  2015
# 7      (47.533010018, -122.275317429)     12  2014
# 8      (47.718291369, -122.291137899)      1  2015
# 9       (47.71850811, -122.312648079)      1  2015
# 10      (47.66796373, -122.380891529)      1  2015
# 11     (47.546473707, -122.290296838)      1  2015
# 12     (47.609812736, -122.342879606)      1  2015
# 13     (47.677749852, -122.367115101)      1  2015
# 14     (47.624661693, -122.320936668)      1  2015
# 15     (47.530883424, -122.322841637)      1  2015
# 16     (47.602412415, -122.331082197)      1  2015
# 17     (47.546024694, -122.275991629)      1  2015
# 18     (47.711246133, -122.366804682)      1  2015
# 19     (47.610034578, -122.323473243)      1  2015
# 20     (47.634814126, -122.402362099)      1  2015
# 21     (47.634814126, -122.402362099)     12  2012
# 22     (47.520471662, -122.337347996)      1  2015
# 23      (47.61635574, -122.323962382)      1  2015
# 24     (47.665957389, -122.382666328)      1  2015
# 25     (47.610034578, -122.323473243)      1  2015
# 26      (47.617308877, -122.35316864)      1  2015
# 27     (47.600464242, -122.330807499)      1  2015
# 28     (47.613519513, -122.320771379)      1  2015
# 29     (47.610963585, -122.340455699)      1  2015
# ...                               ...    ...   ...
# 30784   (47.59031001, -122.335119446)      1  2015
# 30785   (47.637506778, -122.32589712)      1  2015
# 30786  (47.609748463, -122.337793004)      1  2015
# 30787  (47.609781734, -122.339358067)      1  2015
# 30788  (47.609748463, -122.337793004)      1  2015
# 30789  (47.549475589, -122.322836243)      1  2015
# 30790  (47.663996256, -122.313087958)     11  2014
# 30791  (47.600464242, -122.330807499)      1  2015
# 30792  (47.537044025, -122.282344887)      1  2015
# 30793  (47.605719689, -122.320749191)      1  2015
# 30794  (47.610034578, -122.323473243)      1  2015
# 30795   (47.588869846, -122.29488216)      1  2015
# 30796  (47.685922938, -122.326974545)      1  2015
# 30797  (47.596647705, -122.310280931)      1  2015
# 30798  (47.681399455, -122.327082564)      1  2015
# 30799  (47.622554088, -122.319915463)      1  2015
# 30800  (47.677749852, -122.367115101)      1  2015
# 30801  (47.711246133, -122.366804682)      1  2015
# 30802  (47.609812736, -122.342879606)      1  2015
# 30803  (47.610275592, -122.339815384)      1  2015
# 30804  (47.608226866, -122.334870203)      1  2015
# 30805  (47.520174481, -122.376792263)      1  2015
# 30806  (47.537959867, -122.270506606)      1  2015
# 30807  (47.546024694, -122.275991629)      1  2015
# 30808  (47.545334393, -122.329590996)      1  2015
# 30809  (47.602412415, -122.331082197)      1  2015
# 30810  (47.520145885, -122.269721872)      1  2015
# 30811  (47.589210933, -122.310544726)      1  2015
# 30812  (47.720542203, -122.360955642)      1  2015
# 30813  (47.530883424, -122.322841637)      1  2015
#
# [30814 rows x 19 columns]
