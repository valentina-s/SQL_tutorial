# %% [markdown]
# <img src="http://escience.washington.edu/wp-content/uploads/2016/02/DataScienceForSocialGood.png" width = "550">
#
#
# ### SQL Tutorial
#
# #### Friday June 17, 9 am - 12 pm
#
# #### Instructors
# Valentina Staneva, Bill Howe, Anthony Arendt

# %% [markdown]
# #### 1) How many "TRESPASS" offenses occurred in total?
# <br>
# #### 2) What is the most common crime in the dataset, and in what year and month did these occur?
# <br>
# #### 3) What is the most common crime within 5 km of my house?
# <br><br>
# <small>Data source: "SeattleCrimeIncidents.csv" or http://www.seattle.gov/seattle-police-department/crime-data/spd-data-sets

# %% [markdown]
# #### What is a database?
# * software system for capturing, storing and analyzing data
# * nearly all databases use the _relational_ data model

# %% [markdown]
# #### Relational data model:
# * data are structured into row/column format
#
# <br>
#
# | Offense type | Offense code | Date | Location |
# | ---- | ----- | ---- | ---- | ---- |
# |  <small>tresspass | <small>5700 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |
# |  <small>larceny-theft | <small>2300 | <small> 2015-02-21 08:24:21 | <small> 15XX Block of Aurora St |

# %% [markdown]
# 1. uses Structured Query Language (SQL)
# 2. the user dictates the information and analysis needed, and the software takes care of implmenetation details

# %%
# %load_ext sql
# %sql postgresql://awsdssg:datascience2016@dssg2016.cel0foggtnsk.us-east-1.rds.amazonaws.com/dssg2016
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: awsdssg@dssg2016'

# %%
# %%sql
# SELECT COUNT(*) FROM seattlecrimeincidents WHERE "Offense Type" = 'TRESPASS'
# Out:
# 1 rows affected.
# [(710,)]

# %%
# %%sql
# SELECT "Year", "Month", "Offense Type", count(*) as incident_count
#   FROM seattlecrimeincidents
#  GROUP BY "Offense Type", "Year", "Month"
#  ORDER BY "incident_count" DESC
# Out:
# 968 rows affected.
# [(2015, 1, 'THEFT-CARPROWL', 1163),
#  (2015, 5, 'THEFT-CARPROWL', 949),
#  (2015, 4, 'THEFT-CARPROWL', 829),
#  (2015, 3, 'THEFT-CARPROWL', 800),
#  (2015, 2, 'THEFT-CARPROWL', 783),
#  (2015, 6, 'THEFT-CARPROWL', 734),
#  (2015, 1, 'VEH-THEFT-AUTO', 422),
#  (2015, 1, 'THEFT-OTH', 390),
#  (2015, 1, 'BURGLARY-FORCE-RES', 316),
#  (2015, 3, 'THEFT-OTH', 300),
#  (2015, 5, 'THEFT-OTH', 291),
#  (2015, 1, 'PROPERTY DAMAGE-NON RESIDENTIA', 285),
#  (2015, 3, 'VEH-THEFT-AUTO', 281),
#  (2015, 4, 'VEH-THEFT-AUTO', 280),
#  (2015, 4, 'THEFT-OTH', 279),
#  (2015, 5, 'DISTURBANCE-OTH', 277),
#  (2015, 6, 'THEFT-OTH', 274),
#  (2015, 1, 'THEFT-SHOPLIFT', 247),
#  (2015, 4, 'PROPERTY DAMAGE-NON RESIDENTIA', 244),
#  (2015, 1, 'DISTURBANCE-OTH', 242),
#  (2015, 2, 'VEH-THEFT-AUTO', 242),
#  (2015, 5, 'BURGLARY-FORCE-RES', 238),
#  (2015, 3, 'PROPERTY DAMAGE-NON RESIDENTIA', 237),
#  (2015, 6, 'DISTURBANCE-OTH', 237),
#  (2015, 5, 'ASSLT-NONAGG', 235),
#  (2015, 5, 'PROPERTY DAMAGE-NON RESIDENTIA', 235),
#  (2015, 2, 'THEFT-OTH', 219),
#  (2015, 5, 'VEH-THEFT-AUTO', 218),
#  (2015, 3, 'BURGLARY-FORCE-RES', 217),
#  (2015, 3, 'THEFT-SHOPLIFT', 217),
#  (2015, 4, 'DISTURBANCE-OTH', 215),
#  (2015, 4, 'FRAUD-IDENTITY THEFT', 210),
#  (2015, 6, 'VEH-THEFT-AUTO', 210),
#  (2015, 1, 'PROPERTY FOUND', 209),
#  (2015, 1, 'ASSLT-NONAGG', 209),
#  (2015, 4, 'BURGLARY-FORCE-RES', 206),
#  (2015, 6, 'PROPERTY DAMAGE-NON RESIDENTIA', 204),
#  (2015, 3, 'DISTURBANCE-OTH', 201),
#  (2015, 3, 'PROPERTY FOUND', 198),
#  (2015, 4, 'ASSLT-NONAGG', 196),
#  (2015, 5, 'THEFT-SHOPLIFT', 196),
#  (2015, 2, 'PROPERTY DAMAGE-NON RESIDENTIA', 195),
#  (2015, 4, 'THEFT-SHOPLIFT', 191),
#  (2015, 3, 'ASSLT-NONAGG', 190),
#  (2015, 6, 'ASSLT-NONAGG', 189),
#  (2015, 2, 'THEFT-SHOPLIFT', 187),
#  (2015, 2, 'ASSLT-NONAGG', 186),
#  (2015, 2, 'BURGLARY-FORCE-RES', 186),
#  (2015, 2, 'DISTURBANCE-OTH', 181),
#  (2015, 5, 'PROPERTY FOUND', 181),
#  (2015, 5, 'THEFT-BICYCLE', 180),
#  (2015, 6, 'BURGLARY-FORCE-RES', 173),
#  (2015, 4, 'PROPERTY FOUND', 172),
#  (2015, 3, 'FRAUD-IDENTITY THEFT', 172),
#  (2015, 6, 'THEFT-SHOPLIFT', 168),
#  (2015, 6, 'PROPERTY FOUND', 160),
#  (2015, 1, 'BURGLARY-NOFORCE-RES', 160),
#  (2015, 3, 'THEFT-BUILDING', 155),
#  (2015, 1, 'THEFT-BUILDING', 154),
#  (2015, 5, 'BURGLARY-NOFORCE-RES', 150),
#  (2015, 4, 'BURGLARY-NOFORCE-RES', 145),
#  (2015, 2, 'THEFT-BUILDING', 142),
#  (2015, 3, 'BURGLARY-NOFORCE-RES', 134),
#  (2015, 2, 'PROPERTY FOUND', 134),
#  (2015, 1, 'TRESPASS', 134),
#  (2015, 1, 'WARRARR-FELONY', 131),
#  (2015, 1, 'BURGLARY-FORCE-NONRES', 130),
#  (2015, 5, 'THEFT-BUILDING', 129),
#  (2015, 6, 'THEFT-BICYCLE', 128),
#  (2015, 6, 'BURGLARY-NOFORCE-RES', 127),
#  (2015, 3, 'TRESPASS', 125),
#  (2015, 2, 'FRAUD-IDENTITY THEFT', 125),
#  (2015, 5, 'BURGLARY-FORCE-NONRES', 122),
#  (2015, 4, 'TRESPASS', 121),
#  (2015, 3, 'BURGLARY-FORCE-NONRES', 118),
#  (2015, 5, 'TRESPASS', 117),
#  (2015, 4, 'THEFT-BICYCLE', 117),
#  (2015, 6, 'TRESPASS', 114),
#  (2015, 4, 'THEFT-BUILDING', 109),
#  (2015, 5, 'BURGLARY-SECURE PARKING-RES', 104),
#  (2015, 4, 'BURGLARY-SECURE PARKING-RES', 104),
#  (2015, 1, 'FRAUD-IDENTITY THEFT', 103),
#  (2015, 6, 'THEFT-BUILDING', 103),
#  (2015, 3, 'THEFT-BICYCLE', 102),
#  (2015, 2, 'THEFT-BICYCLE', 101),
#  (2015, 2, 'BURGLARY-NOFORCE-RES', 99),
#  (2015, 2, 'TRESPASS', 99),
#  (2015, 1, 'WARRARR-MISDEMEANOR', 97),
#  (2015, 5, 'FRAUD-CREDIT CARD', 97),
#  (2015, 3, 'BURGLARY-SECURE PARKING-RES', 97),
#  (2015, 6, 'WARRARR-FELONY', 96),
#  (2015, 4, 'FRAUD-CREDIT CARD', 95),
#  (2015, 6, 'BURGLARY-SECURE PARKING-RES', 94),
#  (2015, 4, 'BURGLARY-FORCE-NONRES', 94),
#  (2015, 5, 'WARRARR-FELONY', 93),
#  (2015, 1, 'THEFT-BICYCLE', 92),
#  (2015, 2, 'BURGLARY-FORCE-NONRES', 89),
#  (2015, 1, 'BURGLARY-SECURE PARKING-RES', 79),
#  (2015, 5, 'HARASSMENT', 77),
#  (2015, 4, 'WARRARR-FELONY', 77),
#  (2015, 1, 'FRAUD-CREDIT CARD', 75),
#  (2015, 1, 'PROPERTY DAMAGE - GRAFFITI', 75),
#  (2015, 1, 'PROPERTY DAMAGE-RESIDENTIAL', 74),
#  (2015, 6, 'FRAUD-CREDIT CARD', 74),
#  (2015, 3, 'WARRARR-FELONY', 73),
#  (2015, 1, 'ASSLT-AGG-WEAPON', 73),
#  (2015, 4, 'HARASSMENT', 72),
#  (2015, 4, 'PROPERTY DAMAGE-RESIDENTIAL', 71),
#  (2015, 2, 'FRAUD-CREDIT CARD', 70),
#  (2015, 2, 'WARRARR-FELONY', 69),
#  (2015, 5, 'PROPERTY DAMAGE - GRAFFITI', 69),
#  (2015, 4, 'WARRARR-MISDEMEANOR', 69),
#  (2015, 1, 'FRAUD-OTHER', 68),
#  (2015, 5, 'PROPERTY DAMAGE-RESIDENTIAL', 68),
#  (2015, 2, 'BURGLARY-SECURE PARKING-RES', 66),
#  (2015, 6, 'ASSLT-AGG-WEAPON', 66),
#  (2015, 2, 'HARASSMENT', 66),
#  (2015, 1, 'HARASSMENT', 65),
#  (2015, 5, 'ASSLT-AGG-WEAPON', 65),
#  (2015, 1, 'BURGLARY-NOFORCE-NONRES', 65),
#  (2015, 3, 'WARRARR-MISDEMEANOR', 65),
#  (2015, 1, 'ROBBERY-STREET-BODYFORCE', 65),
#  (2015, 2, 'PROPERTY DAMAGE - GRAFFITI', 65),
#  (2015, 6, 'BURGLARY-FORCE-NONRES', 64),
#  (2015, 5, 'FRAUD-IDENTITY THEFT', 64),
#  (2015, 3, 'PROPERTY DAMAGE - GRAFFITI', 64),
#  (2015, 2, 'PROPERTY DAMAGE-RESIDENTIAL', 61),
#  (2015, 1, 'THEFT-LICENSE PLATE', 60),
#  (2015, 3, 'FRAUD-CREDIT CARD', 60),
#  (2015, 6, 'HARASSMENT', 60),
#  (2015, 5, 'THREATS-OTHER', 59),
#  (2015, 5, 'WARRARR-MISDEMEANOR', 59),
#  (2015, 3, 'THEFT-LICENSE PLATE', 59),
#  (2015, 3, 'PROPERTY DAMAGE-RESIDENTIAL', 59),
#  (2015, 6, 'PROPERTY DAMAGE-RESIDENTIAL', 58),
#  (2015, 3, 'BURGLARY-NOFORCE-NONRES', 58),
#  (2015, 3, 'HARASSMENT', 58),
#  (2015, 3, 'ASSLT-AGG-WEAPON', 57),
#  (2015, 2, 'ASSLT-AGG-WEAPON', 57),
#  (2015, 1, 'TRAFFIC', 56),
#  (2015, 6, 'BURGLARY-NOFORCE-NONRES', 54),
#  (2015, 1, 'PROSTITUTION PATRONIZING', 54),
#  (2015, 2, 'WARRARR-MISDEMEANOR', 54),
#  (2015, 6, 'WARRARR-MISDEMEANOR', 53),
#  (2015, 3, 'THREATS-OTHER', 53),
#  (2015, 5, 'BURGLARY-NOFORCE-NONRES', 52),
#  (2015, 5, 'ROBBERY-STREET-BODYFORCE', 52),
#  (2014, 12, 'THEFT-CARPROWL', 52),
#  (2015, 3, 'ROBBERY-STREET-BODYFORCE', 52),
#  (2015, 4, 'THREATS-OTHER', 52),
#  (2015, 1, 'THREATS-OTHER', 51),
#  (2015, 6, 'TRAFFIC', 51),
#  (2015, 1, 'ROBBERY-BUSINESS-BODYFORCE', 51),
#  (2015, 2, 'BURGLARY-NOFORCE-NONRES', 49),
#  (2015, 6, 'ROBBERY-STREET-BODYFORCE', 49),
#  (2015, 4, 'PROPERTY DAMAGE - GRAFFITI', 48),
#  (2015, 4, 'ROBBERY-STREET-BODYFORCE', 48),
#  (2015, 1, 'THEFT-MAIL', 48),
#  (2015, 6, 'PROPERTY DAMAGE - GRAFFITI', 48),
#  (2015, 4, 'ASSLT-AGG-WEAPON', 47),
#  (2015, 5, 'TRAFFIC', 46),
#  (2015, 6, 'THREATS-OTHER', 46),
#  (2015, 1, 'THREATS-KILL', 46),
#  (2015, 3, 'TRAFFIC', 45),
#  (2015, 4, 'BURGLARY-NOFORCE-NONRES', 42),
#  (2015, 4, 'THEFT-LICENSE PLATE', 42),
#  (2015, 2, 'THEFT-LICENSE PLATE', 41),
#  (2015, 1, 'VEH-THEFT-TRUCK', 40),
#  (2015, 2, 'THREATS-OTHER', 40),
#  (2015, 3, 'THEFT-AUTOACC', 40),
#  (2015, 6, 'FRAUD-IDENTITY THEFT', 39),
#  (2015, 2, 'TRAFFIC', 39),
#  (2015, 6, 'THEFT-LICENSE PLATE', 39),
#  (2015, 5, 'THEFT-LICENSE PLATE', 39),
#  (2014, 12, 'THEFT-OTH', 38),
#  (2015, 1, 'PROPERTY LOST', 38),
#  (2015, 4, 'TRAFFIC', 36),
#  (2015, 1, 'THEFT-AUTOACC', 35),
#  (2015, 1, 'FRAUD-CHECK', 35),
#  (2015, 2, 'ROBBERY-STREET-BODYFORCE', 35),
#  (2015, 4, 'COUNTERFEIT', 34),
#  (2015, 2, 'THEFT-MAIL', 33),
#  (2015, 2, 'THEFT-AUTOACC', 33),
#  (2015, 5, 'FRAUD-OTHER', 32),
#  (2015, 4, 'THEFT-MAIL', 32),
#  (2015, 1, 'THEFT OF SERVICES', 32),
#  (2015, 2, 'FRAUD-OTHER', 31),
#  (2015, 3, 'THEFT-MAIL', 31),
#  (2015, 3, 'FRAUD-OTHER', 31),
#  (2014, 12, 'FRAUD-IDENTITY THEFT', 31),
#  (2015, 1, 'ASSLT-AGG-GUN', 29),
#  (2015, 1, 'DISPUTE-OTH', 28),
#  (2015, 3, 'THREATS-KILL', 28),
#  (2015, 2, 'FRAUD-CHECK', 28),
#  (2015, 3, 'PROPERTY LOST', 28),
#  (2015, 5, 'THREATS-KILL', 28),
#  (2015, 5, 'FRAUD-CHECK', 27),
#  (2015, 4, 'THREATS-KILL', 27),
#  (2015, 6, 'PROPERTY LOST', 27),
#  (2015, 2, 'THREATS-KILL', 27),
#  (2014, 12, 'VEH-THEFT-AUTO', 26),
#  (2015, 4, 'FRAUD-CHECK', 26),
#  (2015, 3, 'ROBBERY-BUSINESS-BODYFORCE', 25),
#  (2015, 2, 'PROPERTY STOLEN-POSSESS', 24),
#  (2015, 3, 'FRAUD-CHECK', 24),
#  (2015, 5, 'THEFT-MAIL', 24),
#  (2015, 6, 'THREATS-KILL', 24),
#  (2015, 2, 'ASSLT-AGG-BODYFORCE', 23),
#  (2015, 2, 'PROPERTY LOST', 23),
#  (2015, 5, 'DISPUTE-OTH', 23),
#  (2015, 5, 'ASSLT-AGG-BODYFORCE', 23),
#  (2015, 4, 'PROSTITUTION', 23),
#  (2015, 6, 'PROSTITUTION', 23),
#  (2015, 6, 'ASSLT-AGG-BODYFORCE', 23),
#  (2015, 1, 'THEFT-PKPOCKET', 22),
#  (2014, 12, 'BURGLARY-FORCE-RES', 22),
#  (2015, 2, 'NARC-POSSESS-HEROIN', 22),
#  (2015, 2, 'ROBBERY-BUSINESS-BODYFORCE', 22),
#  (2015, 1, 'VEH-THEFT-MTRCYCLE', 22),
#  (2015, 5, 'VEH-THEFT-MTRCYCLE', 22),
#  (2015, 5, 'PROSTITUTION', 21),
#  (2015, 2, 'THEFT-PKPOCKET', 21),
#  (2015, 5, 'THEFT-AUTOACC', 21),
#  (2015, 4, 'FRAUD-OTHER', 21),
#  (2015, 1, 'ASSLT-AGG-BODYFORCE', 21),
#  (2015, 1, 'ASSLT-NONAGG-POLICE', 20),
#  (2015, 5, 'THEFT OF SERVICES', 20),
#  (2015, 3, 'NARC-POSSESS-HEROIN', 20),
#  (2015, 3, 'VEH-RCVD-FOR OTHER AGENCY', 20),
#  (2014, 11, 'FRAUD-CREDIT CARD', 20),
#  (2015, 4, 'THEFT OF SERVICES', 20),
#  (2015, 5, 'PROPERTY LOST', 20),
#  (2015, 4, 'THEFT-AUTOACC', 20),
#  (2015, 6, 'VEH-THEFT-MTRCYCLE', 20),
#  (2015, 2, 'NARC-POSSESS-COCAINE', 20),
#  (2015, 1, 'COUNTERFEIT', 19),
#  (2015, 6, 'FRAUD-CHECK', 19),
#  (2015, 3, 'VEH-THEFT-TRUCK', 19),
#  (2015, 4, 'PROPERTY LOST', 19),
#  (2015, 3, 'ASSLT-AGG-BODYFORCE', 19),
#  (2015, 6, 'VIOL-COURT ORDER', 19),
#  (2015, 1, 'WEAPON-POSSESSION', 19),
#  (2015, 5, 'VEH-THEFT-TRUCK', 18),
#  (2015, 5, 'ROBBERY-BUSINESS-BODYFORCE', 18),
#  (2015, 1, 'VEH-RCVD-FOR OTHER AGENCY', 18),
#  (2015, 3, 'COUNTERFEIT', 18),
#  (2015, 3, 'VEH-THEFT-MTRCYCLE', 18),
#  (2015, 4, 'THEFT-PKPOCKET', 17),
#  (2014, 12, 'THEFT-MAIL', 17),
#  (2015, 1, 'NARC-POSSESS-HEROIN', 17),
#  (2015, 2, 'ROBBERY-STREET-WEAPON', 17),
#  (2015, 4, 'ASSLT-AGG-BODYFORCE', 17),
#  (2015, 4, 'ROBBERY-BUSINESS-BODYFORCE', 17),
#  (2015, 3, 'DISPUTE-CIVIL PROPERTY (NON AU', 17),
#  (2015, 6, 'THEFT OF SERVICES', 17),
#  (2015, 1, 'WARRANT-FUGITIVE', 17),
#  (2014, 12, 'BURGLARY-NOFORCE-RES', 17),
#  (2015, 1, 'NARC-SELL-COCAINE', 17),
#  (2015, 2, 'ASSLT-AGG-GUN', 17),
#  (2015, 6, 'ROBBERY-STREET-WEAPON', 16),
#  (2015, 3, 'WEAPON-POSSESSION', 16),
#  (2015, 2, 'COUNTERFEIT', 16),
#  (2015, 4, 'NARC-POSSESS-HEROIN', 16),
#  (2015, 2, 'THREATS-WEAPON', 16),
#  (2015, 2, 'VEH-THEFT-TRUCK', 16),
#  (2015, 1, 'ROBBERY-STREET-GUN', 16),
#  (2015, 3, 'THREATS-WEAPON', 16),
#  (2015, 1, 'NARC-POSSESS-COCAINE', 16),
#  (2015, 5, 'DISPUTE-CIVIL PROPERTY (NON AU', 16),
#  (2015, 5, 'ROBBERY-STREET-GUN', 16),
#  (2015, 3, 'THEFT OF SERVICES', 15),
#  (2015, 1, 'PROPERTY STOLEN-POSSESS', 15),
#  (2015, 2, 'WEAPON-DISCHARGE', 15),
#  (2015, 5, 'NARC-SELL-COCAINE', 15),
#  (2015, 5, 'COUNTERFEIT', 15),
#  (2015, 1, 'DISTURBANCE-NOISE', 15),
#  (2015, 6, 'ROBBERY-BUSINESS-BODYFORCE', 15),
#  (2015, 1, 'THREATS-WEAPON', 15),
#  (2015, 1, 'FRAUD-WIRE-ELECTRONIC', 15),
#  (2014, 12, 'FRAUD-CREDIT CARD', 15),
#  (2015, 5, 'PROPERTY STOLEN-POSSESS', 15),
#  (2015, 5, 'THEFT-PKPOCKET', 15),
#  (2015, 4, 'VEH-RCVD-FOR OTHER AGENCY', 15),
#  (2014, 12, 'THEFT-BICYCLE', 15),
#  (2015, 5, 'NARC-POSSESS-COCAINE', 14),
#  (2015, 1, 'VIOL-COURT ORDER', 14),
#  (2015, 2, 'NARC-SELL-COCAINE', 14),
#  (2015, 2, 'DISPUTE-OTH', 14),
#  (2015, 3, 'PROPERTY STOLEN-POSSESS', 14),
#  (2015, 5, 'VEH-RCVD-FOR OTHER AGENCY', 14),
#  (2014, 12, 'FRAUD-CHECK', 14),
#  (2015, 6, 'VEH-RCVD-FOR OTHER AGENCY', 14),
#  (2015, 1, 'NARC-POSSESS-METH', 14),
#  (2015, 3, 'ROBBERY-STREET-GUN', 13),
#  (2015, 2, 'VEH-RCVD-FOR OTHER AGENCY', 13),
#  (2015, 5, 'DISTURBANCE-NOISE', 13),
#  (2015, 2, 'ROBBERY-STREET-GUN', 13),
#  (2015, 6, 'NARC-SELL-COCAINE', 13),
#  (2015, 6, 'WEAPON-POSSESSION', 13),
#  (2015, 3, 'ROBBERY-BUSINESS-WEAPON', 13),
#  (2015, 6, 'FRAUD-OTHER', 13),
#  (2015, 3, 'BURGLARY-SECURE PARKING-NONRES', 13),
#  (2015, 4, 'VEH-THEFT-MTRCYCLE', 13),
#  (2015, 4, 'VIOL-COURT ORDER', 12),
#  (2015, 4, 'ASSLT-AGG-GUN', 12),
#  (2015, 1, 'THEFT-AUTO PARTS', 12),
#  (2015, 4, 'BURGLARY-SECURE PARKING-NONRES', 12),
#  (2015, 3, 'VIOL-COURT ORDER', 12),
#  (2014, 11, 'FRAUD-IDENTITY THEFT', 12),
#  (2015, 4, 'PROPERTY STOLEN-POSSESS', 12),
#  (2015, 4, 'VEH-THEFT-TRUCK', 12),
#  (2015, 6, 'DISPUTE-OTH', 12),
#  (2015, 4, 'WEAPON-POSSESSION', 12),
#  (2015, 5, 'LIQUOR LAW VIOLATION', 12),
#  (2015, 4, 'ROBBERY-STREET-WEAPON', 12),
#  (2014, 12, 'THEFT-LICENSE PLATE', 12),
#  (2015, 2, 'VIOL-COURT ORDER', 12),
#  (2015, 3, 'ROBBERY-STREET-WEAPON', 11),
#  (2015, 4, 'WEAPON-DISCHARGE', 11),
#  (2015, 6, 'ROBBERY-STREET-GUN', 11),
#  (2015, 2, 'THEFT OF SERVICES', 11),
#  (2015, 6, 'THEFT-AUTOACC', 11),
#  (2015, 6, 'VEH-THEFT-TRUCK', 11),
#  (2015, 5, 'WEAPON-POSSESSION', 11),
#  (2015, 6, 'PROPERTY STOLEN-POSSESS', 11),
#  (2015, 6, 'THEFT-MAIL', 11),
#  (2015, 6, 'DISTURBANCE-NOISE', 11),
#  (2015, 3, 'NARC-POSSESS-COCAINE', 11),
#  (2015, 1, 'ROBBERY-BUSINESS-WEAPON', 11),
#  (2015, 5, 'THREATS-WEAPON', 11),
#  (2014, 12, 'PROPERTY DAMAGE-NON RESIDENTIA', 11),
#  (2015, 6, 'ASSLT-AGG-GUN', 11),
#  (2015, 6, 'THEFT-PKPOCKET', 11),
#  (2015, 1, 'WEAPON-DISCHARGE', 10),
#  (2015, 6, 'NARC-POSSESS-COCAINE', 10),
#  (2015, 3, 'NARC-SELL-COCAINE', 10),
#  (2015, 2, 'PROSTITUTION', 10),
#  (2015, 1, 'PROSTITUTION', 10),
#  (2015, 1, 'PROP RECOVERED-OTHER AGENCY', 10),
#  (2015, 4, 'EMBEZZLE', 10),
#  (2015, 4, 'ROBBERY-BUSINESS-GUN', 10),
#  (2015, 2, 'DISTURBANCE-NOISE', 10),
#  (2015, 3, 'DISTURBANCE-NOISE', 10),
#  (2014, 12, 'FRAUD-OTHER', 10),
#  (2014, 10, 'FRAUD-IDENTITY THEFT', 10),
#  (2015, 3, 'ROBBERY-BUSINESS-GUN', 10),
#  (2015, 4, 'DISPUTE-OTH', 9),
#  (2015, 2, 'FRAUD-WIRE-ELECTRONIC', 9),
#  (2015, 6, 'THREATS-WEAPON', 9),
#  (2014, 12, 'HARASSMENT', 9),
#  (2015, 2, 'NARC-POSSESS-METH', 9),
#  (2015, 4, 'NARC-FOUND-MARIJU', 9),
#  (2015, 6, 'PROP RECOVERED-OTHER AGENCY', 9),
#  (2015, 5, 'EMBEZZLE', 9),
#  (2015, 1, 'EMBEZZLE', 9),
#  (2014, 12, 'THEFT-BUILDING', 9),
#  (2015, 6, 'EMBEZZLE', 9),
#  (2014, 6, 'THEFT-OTH', 9),
#  (2014, 11, 'THEFT-OTH', 9),
#  (2014, 1, 'FRAUD-IDENTITY THEFT', 9),
#  (2014, 5, 'FRAUD-IDENTITY THEFT', 9),
#  (2015, 6, 'INJURY - OTHER', 9),
#  (2015, 1, 'NARC-SELL-METH', 8),
#  (2015, 4, 'NARC-SELL-COCAINE', 8),
#  (2015, 3, 'FRAUD-WIRE-ELECTRONIC', 8),
#  (2015, 5, 'ASSLT-AGG-GUN', 8),
#  (2015, 1, 'OBSTRUCT', 8),
#  (2015, 2, 'ROBBERY-BUSINESS-GUN', 8),
#  (2015, 6, 'NARC-POSSESS-HEROIN', 8),
#  (2015, 4, 'FALSE REPORT', 8),
#  (2015, 3, 'EMBEZZLE', 8),
#  (2015, 4, 'FRAUD-WIRE-ELECTRONIC', 8),
#  (2015, 5, 'OBSTRUCT', 8),
#  (2015, 5, 'VIOL-COURT ORDER', 8),
#  (2015, 5, 'NARC-POSSESS-HEROIN', 8),
#  (2015, 5, 'PROP RECOVERED-OTHER AGENCY', 8),
#  (2015, 5, 'MALICIOUS HARASSMENT', 8),
#  (2015, 2, 'ASSLT-NONAGG-POLICE', 8),
#  (2015, 1, 'LIQUOR LAW VIOLATION', 7),
#  (2015, 5, 'PROSTITUTION PATRONIZING', 7),
#  (2015, 6, 'PROSTITUTION PATRONIZING', 7),
#  (2015, 2, 'WARRANT-FUGITIVE', 7),
#  (2015, 5, 'ANIMAL-BITE', 7),
#  (2015, 6, 'BURGLARY-SECURE PARKING-NONRES', 7),
#  (2015, 1, 'FALSE REPORT', 7),
#  (2015, 4, 'NARC-POSSESS-COCAINE', 7),
#  (2015, 1, 'RECKLESS BURNING', 7),
#  (2014, 12, 'PROPERTY FOUND', 7),
#  (2015, 2, 'EMBEZZLE', 7),
#  (2015, 6, 'ANIMAL-BITE', 7),
#  (2015, 3, 'OBSTRUCT', 7),
#  (2015, 6, 'NARC-POSSESS-METH', 7),
#  (2015, 5, 'ROBBERY-BUSINESS-WEAPON', 7),
#  (2014, 11, 'FRAUD-CHECK', 7),
#  (2014, 11, 'THEFT-CARPROWL', 7),
#  (2014, 12, 'PROPERTY LOST', 7),
#  (2014, 4, 'FRAUD-IDENTITY THEFT', 7),
#  (2015, 1, 'DUI-LIQUOR', 7),
#  (2015, 4, 'OBSTRUCT', 7),
#  (2015, 2, 'OBSTRUCT', 7),
#  (2015, 4, 'THREATS-WEAPON', 7),
#  (2015, 2, 'FORGERY-CHECK', 7),
#  (2015, 3, 'DISPUTE-OTH', 7),
#  (2014, 12, 'FORGERY-CHECK', 7),
#  (2015, 2, 'WEAPON-POSSESSION', 7),
#  (2015, 5, 'BURGLARY-SECURE PARKING-NONRES', 7),
#  (2015, 4, 'NARC-POSSESS-AMPHETAMINE', 7),
#  (2015, 4, 'NARC-POSSESS-METH', 7),
#  (2015, 4, 'DISPUTE-CIVIL PROPERTY (NON AU', 7),
#  (2015, 6, 'DISPUTE-CIVIL PROPERTY (NON AU', 7),
#  (2015, 4, 'PROSTITUTION PATRONIZING', 7),
#  (2015, 1, 'NARC-FOUND-OTHER', 7),
#  (2015, 4, 'NARC-EQUIPMENT/PARAPHENALIA', 7),
#  (2015, 1, 'ROBBERY-STREET-WEAPON', 6),
#  (2015, 6, 'NARC-FOUND-HEROIN', 6),
#  (2015, 1, 'ANIMAL-BITE', 6),
#  (2015, 6, 'THEFT-AUTO PARTS', 6),
#  (2014, 12, 'BURGLARY-SECURE PARKING-RES', 6),
#  (2015, 3, 'NARC-EQUIPMENT/PARAPHENALIA', 6),
#  (2015, 5, 'ROBBERY-STREET-WEAPON', 6),
#  (2015, 4, 'THEFT-PRSNATCH', 6),
#  (2015, 5, 'NARC-SELL-HEROIN', 6),
#  (2015, 3, 'THEFT-PKPOCKET', 6),
#  (2015, 3, 'ROBBERY-RESIDENCE-GUN', 6),
#  (2015, 1, 'FRAUD-COMPUTER', 6),
#  (2015, 1, 'ANIMAL-OTH', 6),
#  (2015, 5, 'ANIMAL-OTH', 6),
#  (2015, 3, 'NARC-FOUND-OTHER', 6),
#  (2015, 5, 'WEAPON-DISCHARGE', 6),
#  (2015, 5, 'WEAPON-UNLAWFUL USE', 6),
#  (2015, 3, 'ASSLT-NONAGG-POLICE', 6),
#  (2015, 4, 'ROBBERY-STREET-GUN', 6),
#  (2015, 6, 'ANIMAL-OTH', 6),
#  (2015, 3, 'NARC-POSSESS-METH', 6),
#  (2015, 2, 'VEH-THEFT-MTRCYCLE', 6),
#  (2015, 3, 'ASSLT-AGG-GUN', 6),
#  (2014, 12, 'BURGLARY-FORCE-NONRES', 6),
#  (2015, 2, 'BURGLARY-SECURE PARKING-NONRES', 6),
#  (2015, 4, 'INJURY - OTHER', 6),
#  (2015, 3, 'FALSE REPORT', 6),
#  (2014, 12, 'PROPERTY DAMAGE-RESIDENTIAL', 6),
#  (2015, 1, 'DISPUTE-CIVIL PROPERTY (NON AU', 6),
#  (2015, 6, 'WARRANT-FUGITIVE', 6),
#  (2015, 4, 'DUI-LIQUOR', 6),
#  (2014, 12, 'EMBEZZLE', 5),
#  (2015, 5, 'ASSLT-NONAGG-POLICE', 5),
#  (2015, 1, 'NARC-SELL-HEROIN', 5),
#  (2015, 6, 'PROSTITUTION-ASSIST-PROMOTE', 5),
#  (2015, 1, 'BURGLARY-SECURE PARKING-NONRES', 5),
#  (2015, 3, 'FORGERY-CHECK', 5),
#  (2014, 11, 'THEFT-LICENSE PLATE', 5),
#  (2015, 2, 'NARC-EQUIPMENT/PARAPHENALIA', 5),
#  (2015, 4, 'ROBBERY-BUSINESS-WEAPON', 5),
#  (2015, 2, 'DISPUTE-CIVIL PROPERTY (NON AU', 5),
#  (2015, 3, 'WEAPON-DISCHARGE', 5),
#  (2015, 5, 'FORGERY-CHECK', 5),
#  (2015, 6, 'FRAUD-WIRE-ELECTRONIC', 5),
#  (2015, 6, 'NARC-FORGERY-PRESCRIPTION', 5),
#  (2014, 2, 'THEFT-CARPROWL', 5),
#  (2015, 6, 'ROBBERY-BUSINESS-WEAPON', 5),
#  (2014, 3, 'THEFT-BUILDING', 5),
#  (2015, 1, 'NARC-FOUND-HEROIN', 5),
#  (2015, 1, 'FORGERY-CHECK', 5),
#  (2015, 4, 'NARC-FOUND-OTHER', 5),
#  (2015, 4, 'ASSLT-NONAGG-POLICE', 5),
#  (2015, 5, 'INJURY - OTHER', 5),
#  (2014, 12, 'PROPERTY DAMAGE - GRAFFITI', 5),
#  (2015, 6, 'NARC-FOUND-OTHER', 5),
#  (2015, 4, 'DISTURBANCE-NOISE', 5),
#  (2015, 2, 'ANIMAL-OTH', 5),
#  (2015, 3, 'DUI-LIQUOR', 5),
#  (2015, 1, 'THEFT-COINOP', 5),
#  (2014, 9, 'FRAUD-IDENTITY THEFT', 5),
#  (2015, 6, 'THEFT-PRSNATCH', 5),
#  (2013, 12, 'FRAUD-IDENTITY THEFT', 5),
#  (2015, 3, 'NARC-POSSESS-MARIJU', 5),
#  (2015, 2, 'ROBBERY-BUSINESS-WEAPON', 5),
#  (2015, 3, 'ANIMAL-OTH', 5),
#  (2015, 5, 'FRAUD-WIRE-ELECTRONIC', 5),
#  (2014, 8, 'FRAUD-IDENTITY THEFT', 5),
#  (2015, 4, 'PROP RECOVERED-OTHER AGENCY', 5),
#  (2015, 5, 'NARC-EQUIPMENT/PARAPHENALIA', 5),
#  (2015, 4, 'DISPUTE-CIVIL PROPERTY (AUTO)', 5),
#  (2015, 1, 'ROBBERY-BUSINESS-GUN', 5),
#  (2015, 6, 'COUNTERFEIT', 5),
#  (2007, 10, 'FRAUD-IDENTITY THEFT', 4),
#  (2015, 4, 'ILLEGAL DUMPING', 4),
#  (2015, 5, 'ASSLT-AGG-POLICE-WEAPON', 4),
#  (2014, 10, 'THEFT-OTH', 4),
#  (2015, 5, 'RECKLESS BURNING', 4),
#  (2014, 10, 'FRAUD-CHECK', 4),
#  (2015, 1, 'NARC-POSSESS-AMPHETAMINE', 4),
#  (2015, 1, 'NARC-SELL-AMPHETAMINE', 4),
#  (2015, 3, 'DISORDERLY CONDUCT', 4),
#  (2014, 9, 'PROPERTY LOST', 4),
#  (2015, 5, 'DISPUTE-CIVIL PROPERTY (AUTO)', 4),
#  (2014, 11, 'THEFT-BUILDING', 4),
#  (2014, 12, 'THEFT-AUTOACC', 4),
#  (2015, 4, 'NARC-SELL-MARIJU', 4),
#  (2015, 6, 'VEH-THEFT-TRAILER', 4),
#  (2015, 5, 'NARC-SELL-AMPHETAMINE', 4),
#  (2015, 6, 'NARC-FOUND-METH', 4),
#  (2015, 4, 'ROBBERY-RESIDENCE-WEAPON', 4),
#  (2015, 6, 'NARC-EQUIPMENT/PARAPHENALIA', 4),
#  (2015, 2, 'PROP RECOVERED-OTHER AGENCY', 4),
#  (2015, 6, 'ASSLT-NONAGG-POLICE', 4),
#  (2015, 3, 'DRIVE-BY', 4),
#  (2015, 2, 'PROSTITUTION PATRONIZING', 4),
#  (2014, 10, 'THEFT-BUILDING', 4),
#  (2014, 11, 'COUNTERFEIT', 4),
#  (2015, 6, 'ILLEGAL DUMPING', 4),
#  (2015, 2, 'NARC-FOUND-OTHER', 4),
#  (2015, 1, 'MALICIOUS HARASSMENT', 4),
#  (2015, 3, 'THEFT-AUTO PARTS', 4),
#  (2015, 3, 'PROPERTY STOLEN-TRAFFICKING', 4),
#  (2015, 1, 'ASSLT-AGG-POLICE-WEAPON', 4),
#  (2015, 5, 'NARC-FOUND-MARIJU', 4),
#  (2015, 3, 'LIQUOR LAW VIOLATION', 4),
#  (2015, 3, 'NARC-SELL-HEROIN', 4),
#  (2015, 3, 'FRAUD-COMPUTER', 4),
#  (2015, 1, 'ROBBERY-RESIDENCE-BODYFORCE', 4),
#  (2014, 2, 'FRAUD-IDENTITY THEFT', 4),
#  (2015, 4, 'FRAUD-COMPUTER', 4),
#  (2015, 4, 'NARC-SELL-HEROIN', 4),
#  (2015, 1, 'WEAPON-UNLAWFUL USE', 4),
#  (2014, 9, 'FRAUD-OTHER', 4),
#  (2014, 11, 'BURGLARY-FORCE-NONRES', 4),
#  (2015, 1, 'ENDANGERMENT', 4),
#  (2015, 6, 'DUI-LIQUOR', 4),
#  (2015, 5, 'ROBBERY-RESIDENCE-WEAPON', 4),
#  (2014, 4, 'THEFT-CARPROWL', 4),
#  (2015, 5, 'THEFT-AUTO PARTS', 4),
#  (2015, 2, 'ANIMAL-BITE', 4),
#  (2015, 5, 'DISORDERLY CONDUCT', 4),
#  (2015, 6, 'OBSTRUCT', 4),
#  (2015, 3, 'ANIMAL-BITE', 3),
#  (2014, 12, 'VIOL-COURT ORDER', 3),
#  (2015, 3, 'NARC-SELL-MARIJU', 3),
#  (2015, 2, 'NARC-SELL-METH', 3),
#  (2015, 5, 'THEFT-PRSNATCH', 3),
#  (2015, 3, 'WEAPON-UNLAWFUL USE', 3),
#  (2015, 4, 'THEFT-BOAT', 3),
#  (2015, 3, 'PROSTITUTION', 3),
#  (2015, 3, 'VEH-THEFT-TRAILER', 3),
#  (2015, 5, 'INJURY - ACCIDENTAL', 3),
#  (2014, 4, 'EMBEZZLE', 3),
#  (2015, 2, 'INJURY - OTHER', 3),
#  (2015, 1, 'PROSTITUTION LOITERING', 3),
#  (2015, 1, 'ROBBERY-BANK-BODYFORCE', 3),
#  (2015, 2, 'NARC-DRUG TRAFFIC LOITERING', 3),
#  (2015, 4, 'LIQUOR LAW VIOLATION', 3),
#  (2015, 2, 'THEFT-AUTO PARTS', 3),
#  (2015, 4, 'WEAPON-UNLAWFUL USE', 3),
#  (2015, 3, 'FORGERY-CREDIT CARD', 3),
#  (2015, 6, 'ELUDING-FELONY FLIGHT', 3),
#  (2015, 4, 'FORGERY-OTH', 3),
#  (2014, 3, 'FRAUD-IDENTITY THEFT', 3),
#  (2015, 3, 'PORNOGRAPHY-OBSCENE MATERIAL', 3),
#  (2014, 12, 'BURGLARY-NOFORCE-NONRES', 3),
#  (2015, 2, 'PROPERTY STOLEN-TRAFFICKING', 3),
#  (2015, 6, 'WEAPON-UNLAWFUL USE', 3),
#  (2015, 5, 'ENDANGERMENT', 3),
#  (2015, 6, 'DRIVE-BY', 3),
#  (2015, 4, 'THEFT-AUTO PARTS', 3),
#  (2015, 5, 'ROBBERY-RESIDENCE-BODYFORCE', 3),
#  (2015, 6, 'NARC-FRAUD-PRESCRIPTION', 3),
#  (2015, 3, 'NARC-FOUND-HEROIN', 3),
#  (2015, 4, 'NARC-DRUG TRAFFIC LOITERING', 3),
#  (2014, 10, 'FORGERY-CHECK', 3),
#  (2015, 3, 'FORGERY-OTH', 3),
#  (2015, 5, 'EXTORTION', 3),
#  (2015, 3, 'PROP RECOVERED-OTHER AGENCY', 3),
#  (2015, 4, 'ANIMAL-OTH', 3),
#  (2014, 6, 'THEFT-BUILDING', 3),
#  (2015, 4, 'DISORDERLY CONDUCT', 3),
#  (2014, 11, 'THEFT-MAIL', 3),
#  (2015, 3, 'NARC-FOUND-MARIJU', 3),
#  (2015, 3, 'ELUDING-FELONY FLIGHT', 3),
#  (2015, 5, 'WARRANT-FUGITIVE', 3),
#  (2015, 4, 'ANIMAL-BITE', 3),
#  (2015, 2, 'NARC-FOUND-MARIJU', 3),
#  (2015, 2, 'ROBBERY-RESIDENCE-WEAPON', 3),
#  (2015, 4, 'NARC-FOUND-HEROIN', 3),
#  (2015, 3, 'ASSLT-AGG-POLICE-WEAPON', 3),
#  (2015, 3, 'DISPUTE-CIVIL PROPERTY (AUTO)', 3),
#  (2015, 5, 'ILLEGAL DUMPING', 3),
#  (2015, 5, 'ROBBERY-RESIDENCE-GUN', 3),
#  (2015, 1, 'INJURY - OTHER', 3),
#  (2014, 12, 'THEFT-SHOPLIFT', 3),
#  (2015, 6, 'FORGERY-CHECK', 3),
#  (2015, 4, 'PROPERTY LOST - POLICE EQUIPME', 3),
#  (2015, 6, 'ANIMAL-CRUELTY', 3),
#  (2015, 6, 'WEAPON-SURRENDER-EXCLUDING FIR', 3),
#  (2015, 1, 'ELUDING-FELONY FLIGHT', 3),
#  (2015, 4, 'INJURY - ACCIDENTAL', 3),
#  (2015, 5, 'BIAS INCIDENT', 3),
#  (2015, 5, 'NARC-DRUG TRAFFIC LOITERING', 3),
#  (2014, 11, 'BURGLARY-NOFORCE-RES', 3),
#  (2015, 5, 'THEFT-BOAT', 3),
#  (2015, 1, 'THEFT-PRSNATCH', 3),
#  (2015, 6, 'NARC-SELL-METH', 3),
#  (2015, 2, 'NARC-FORGERY-PRESCRIPTION', 3),
#  (2015, 6, 'RECKLESS BURNING', 3),
#  (2015, 6, 'NARC-FOUND-MARIJU', 3),
#  (2015, 4, 'VEH-THEFT-TRAILER', 3),
#  (2015, 5, 'FRAUD-COMPUTER', 3),
#  (2012, 12, 'FRAUD-IDENTITY THEFT', 3),
#  (2015, 3, 'NARC-DRUG TRAFFIC LOITERING', 3),
#  (2014, 7, 'FRAUD-IDENTITY THEFT', 3),
#  (2015, 5, 'WEAPON-SURRENDER-EXCLUDING FIR', 3),
#  (2015, 3, 'NARC-POSSESS-OTHER', 3),
#  (2015, 5, 'NARC-FOUND-OTHER', 3),
#  (2015, 6, 'WEAPON-DISCHARGE', 3),
#  (2014, 9, 'BURGLARY-NOFORCE-RES', 3),
#  (2015, 4, 'DRIVE-BY', 3),
#  (2014, 9, 'THEFT-OTH', 3),
#  (2015, 4, 'WARRANT-FUGITIVE', 3),
#  (2015, 1, 'NARC-POSSESS-PILL/TABLET', 2),
#  (2015, 1, 'INJURY - ACCIDENTAL', 2),
#  (2014, 12, 'ASSLT-NONAGG', 2),
#  (2014, 11, 'VEH-THEFT-AUTO', 2),
#  (2014, 6, 'BURGLARY-FORCE-RES', 2),
#  (2014, 11, 'FORGERY-CHECK', 2),
#  (2015, 3, 'NARC-PRODUCE-MARIJU', 2),
#  (2014, 8, 'FRAUD-CREDIT CARD', 2),
#  (2015, 5, 'FORGERY-CREDIT CARD', 2),
#  (2015, 2, 'ASSLT-AGG-POLICE-WEAPON', 2),
#  (2015, 5, 'NARC-FOUND-HEROIN', 2),
#  (2014, 6, 'BURGLARY-NOFORCE-RES', 2),
#  (2015, 2, 'LIQUOR LAW VIOLATION', 2),
#  (2015, 2, 'NARC-SELL-HEROIN', 2),
#  (2015, 5, 'VEH-THEFT-TRAILER', 2),
#  (2015, 2, 'WEAPON-UNLAWFUL USE', 2),
#  (2014, 10, 'FRAUD-CREDIT CARD', 2),
#  (2015, 5, 'NARC-FOUND-METH', 2),
#  (2015, 3, '[INC - CASE DC USE ONLY]', 2),
#  (2015, 3, 'NARC-SELL-METH', 2),
#  (2014, 4, 'HARASSMENT', 2),
#  (2014, 11, 'FRAUD-OTHER', 2),
#  (2014, 12, 'VEH-THEFT-TRAILER', 2),
#  (2015, 4, 'PROPERTY STOLEN-TRAFFICKING', 2),
#  (2015, 3, 'EXTORTION', 2),
#  (2015, 2, 'ASSLT-AGG-POLICE-BODYFORCE', 2),
#  (2014, 1, 'ASSLT-NONAGG', 2),
#  (2013, 6, 'FRAUD-IDENTITY THEFT', 2),
#  (2015, 3, 'HOMICIDE-PREMEDITATED-GUN', 2),
#  (2015, 2, 'FORGERY-OTH', 2),
#  (2015, 5, 'NARC-POSSESS-METH', 2),
#  (2014, 8, 'THEFT-CARPROWL', 2),
#  (2015, 2, 'NARC-POSSESS-MARIJU', 2),
#  (2015, 2, 'FIREWORK-USE', 2),
#  (2014, 10, 'HARASSMENT', 2),
#  (2014, 12, 'VEH-THEFT-TRUCK', 2),
#  (2010, 5, 'FRAUD-IDENTITY THEFT', 2),
#  (2015, 1, 'ILLEGAL DUMPING', 2),
#  (2013, 8, 'HARASSMENT', 2),
#  (2012, 7, 'FRAUD-IDENTITY THEFT', 2),
#  (2015, 1, 'NARC-SELL-MARIJU', 2),
#  (2014, 7, 'FRAUD-CHECK', 2),
#  (2015, 4, 'PROSTITUTION LOITERING', 2),
#  (2015, 5, 'NARC-FORGERY-PRESCRIPTION', 2),
#  (2015, 6, 'MALICIOUS HARASSMENT', 2),
#  (2014, 2, 'FRAUD-CREDIT CARD', 2),
#  (2014, 11, 'BURGLARY-SECURE PARKING-RES', 2),
#  (2014, 12, 'VEH-THEFT-MTRCYCLE', 2),
#  (2015, 4, 'NARC-FOUND-COCAINE', 2),
#  (2015, 3, 'PROPERTY LOST - POLICE EQUIPME', 2),
#  (2015, 2, 'THEFT-COINOP', 2),
#  (2015, 3, 'NARC-FOUND-COCAINE', 2),
#  (2015, 5, 'NARC-FOUND-PILL/TABLET', 2),
#  (2014, 3, 'URINATING/DEFECATING-IN PUBLIC', 2),
#  (2015, 4, 'ROBBERY-RESIDENCE-GUN', 2),
#  (2015, 1, 'NARC-POSSESS-PRESCRIPTION', 2),
#  (2015, 1, 'NARC-DRUG TRAFFIC LOITERING', 2),
#  (2015, 1, 'ASSLT-AGG-POLICE-BODYFORCE', 2),
#  (2015, 4, 'NARC-FOUND-METH', 2),
#  (2015, 2, 'FORGERY-CREDIT CARD', 2),
#  (2015, 6, 'THEFT-COINOP', 2),
#  (2015, 3, 'INJURY - ACCIDENTAL', 2),
#  (2014, 1, 'THEFT-OTH', 2),
#  (2014, 9, 'THEFT-CARPROWL', 2),
#  (2014, 4, 'NARC-POSSESS-HEROIN', 2),
#  (2015, 4, 'ENDANGERMENT', 2),
#  (2015, 2, 'ROBBERY-RESIDENCE-BODYFORCE', 2),
#  (2012, 1, 'FRAUD-IDENTITY THEFT', 2),
#  (2014, 1, 'THEFT-BICYCLE', 2),
#  (2015, 5, '[INC - CASE DC USE ONLY]', 2),
#  (2013, 1, 'THEFT-OTH', 2),
#  (2015, 4, 'ROBBERY-RESIDENCE-BODYFORCE', 2),
#  (2015, 5, 'NARC-POSSESS-AMPHETAMINE', 2),
#  (2015, 5, 'ASSLT-AGG-POLICE-BODYFORCE', 2),
#  (2015, 3, 'WEAPON-CONCEALED', 2),
#  (2015, 3, 'HOMICIDE-PREMEDITATED-WEAPON', 2),
#  (2015, 1, 'NARC-EQUIPMENT/PARAPHENALIA', 2),
#  (2015, 4, 'FORGERY-CREDIT CARD', 2),
#  (2015, 2, 'NARC-FOUND-METH', 2),
#  (2014, 5, 'THEFT-OTH', 2),
#  (2015, 3, 'MALICIOUS HARASSMENT', 2),
#  (2014, 1, 'THEFT-BUILDING', 2),
#  (2015, 2, 'VEH-THEFT-TRAILER', 2),
#  (2015, 1, '[INC - CASE DC USE ONLY]', 2),
#  (2015, 1, 'NARC-FOUND-AMPHETAMINE', 2),
#  (2015, 4, 'PROPERTY STOLEN-SELL', 2),
#  (2014, 10, 'BURGLARY-NOFORCE-RES', 2),
#  (2015, 6, 'PROPERTY LOST - POLICE EQUIPME', 2),
#  (2015, 5, 'NARC-FOUND-COCAINE', 2),
#  (2015, 1, 'NARC-FRAUD-PRESCRIPTION', 2),
#  (2015, 5, 'NARC-SELL-OTHER', 2),
#  (2015, 3, 'WARRANT-FUGITIVE', 2),
#  (2013, 10, 'FRAUD-OTHER', 2),
#  (2015, 3, 'ILLEGAL DUMPING', 2),
#  (2015, 5, 'PROPERTY LOST - POLICE EQUIPME', 2),
#  (2015, 1, 'ESCAPE', 2),
#  (2014, 12, 'PROPERTY LOST - POLICE EQUIPME', 2),
#  (2014, 9, 'FRAUD-CREDIT CARD', 2),
#  (2015, 1, 'NARC-POSSESS-OTHER', 2),
#  (2015, 2, 'ELUDING-FELONY FLIGHT', 2),
#  (2015, 2, 'DUI-LIQUOR', 2),
#  (2015, 1, 'PROPERTY LOST - POLICE EQUIPME', 2),
#  (2013, 6, 'EMBEZZLE', 2),
#  (2013, 3, 'FRAUD-IDENTITY THEFT', 2),
#  (2015, 3, 'INJURY - OTHER', 2),
#  (2015, 4, 'ANIMAL-CRUELTY', 2),
#  (2015, 2, 'ILLEGAL DUMPING', 2),
#  (2015, 4, 'WEAPON-SURRENDER-EXCLUDING FIR', 2),
#  (2015, 3, 'NARC-FORGERY-PRESCRIPTION', 2),
#  (2015, 1, 'URINATING/DEFECATING-IN PUBLIC', 2),
#  (2011, 1, 'BURGLARY-SECURE PARKING-RES', 2),
#  (2015, 2, 'RECKLESS BURNING', 2),
#  (2015, 6, 'ASSLT-AGG-POLICE-WEAPON', 2),
#  (2015, 2, 'DISPUTE-CIVIL PROPERTY (AUTO)', 2),
#  (2015, 2, 'HOMICIDE-PREMEDITATED-BODYFORC', 2),
#  (2014, 1, 'THEFT-MAIL', 2),
#  (2015, 1, 'NARC-POSSESS-MARIJU', 2),
#  (2015, 5, 'PROSTITUTION LOITERING', 2),
#  (2015, 6, 'FRAUD-COMPUTER', 2),
#  (2015, 3, 'ROBBERY-BANK-GUN', 1),
#  (2014, 5, 'THEFT-BUILDING', 1),
#  (2013, 4, 'THEFT-LICENSE PLATE', 1),
#  (2013, 5, 'PROPERTY LOST', 1),
#  (2014, 9, 'FRAUD-CHECK', 1),
#  (2015, 1, 'NARC-FOUND-MARIJU', 1),
#  (2012, 9, 'FRAUD-IDENTITY THEFT', 1),
#  (2015, 3, 'ENDANGERMENT', 1),
#  (2013, 11, 'THEFT-BICYCLE', 1),
#  (2014, 6, 'COUNTERFEIT', 1),
#  (2015, 5, 'PROPERTY RECOVERED - POLICE EQ', 1),
#  (2014, 11, 'PROPERTY FOUND', 1),
#  (2008, 9, 'FRAUD-IDENTITY THEFT', 1),
#  (2014, 4, 'BURGLARY-NOFORCE-RES', 1),
#  (2015, 2, 'EXTORTION', 1),
#  (2015, 6, 'HOMICIDE-PREMEDITATED-GUN', 1),
#  (2015, 2, 'WEAPON-CONCEALED', 1),
#  (2014, 4, 'PROPERTY LOST', 1),
#  (2008, 1, 'FRAUD-IDENTITY THEFT', 1),
#  (2014, 11, 'DISPUTE-CIVIL PROPERTY (NON AU', 1),
#  (2014, 1, 'FRAUD-CHECK', 1),
#  (2014, 7, 'FRAUD-OTHER', 1),
#  (2008, 4, 'HARASSMENT', 1),
#  (2014, 1, 'THEFT-CARPROWL', 1),
#  (2012, 7, 'EMBEZZLE', 1),
#  (2014, 11, 'HARASSMENT', 1),
#  (2014, 10, 'ASSLT-NONAGG', 1),
#  (2012, 7, 'PROPERTY LOST', 1),
#  (2014, 12, 'THEFT-AUTO PARTS', 1),
#  (2015, 1, 'NARC-MANUFACTURE-OTHER', 1),
#  (2015, 6, 'ROBBERY-RESIDENCE-WEAPON', 1),
#  (2010, 1, 'HARASSMENT', 1),
#  (2013, 12, 'EMBEZZLE', 1),
#  (2015, 2, 'BIAS INCIDENT', 1),
#  (2014, 3, 'FRAUD-OTHER', 1),
#  (2015, 3, 'NARC-FOUND-METH', 1),
#  (2014, 6, 'FRAUD-IDENTITY THEFT', 1),
#  (2014, 1, 'FRAUD-OTHER', 1),
#  (2014, 9, 'EMBEZZLE', 1),
#  (2015, 2, 'MALICIOUS HARASSMENT', 1),
#  (2012, 5, 'FRAUD-CHECK', 1),
#  (2014, 7, 'FORGERY-CHECK', 1),
#  (2015, 1, 'BIAS INCIDENT', 1),
#  (2002, 1, 'FRAUD-IDENTITY THEFT', 1),
#  (2015, 6, 'ROBBERY-RESIDENCE-BODYFORCE', 1),
#  (2015, 2, 'NARC-FRAUD-PRESCRIPTION', 1),
#  (2014, 7, 'HARASSMENT', 1),
#  (2011, 4, 'FRAUD-IDENTITY THEFT', 1),
#  (2015, 5, 'DUI-LIQUOR', 1),
#  (2015, 1, 'WEAPON-SURRENDER-EXCLUDING FIR', 1),
#  (2014, 6, 'FRAUD-CHECK', 1),
#  (2008, 6, 'EMBEZZLE', 1),
#  (2015, 4, 'RECKLESS BURNING', 1),
#  (2015, 5, 'NARC-SELL-MARIJU', 1),
#  (2015, 4, 'URINATING/DEFECATING-IN PUBLIC', 1),
#  (2014, 12, 'FALSE REPORT', 1),
#  (2014, 12, 'FORGERY-OTH', 1),
#  (2015, 4, 'FIREWORK-USE', 1),
#  (2015, 6, 'WEAPON-CONCEALED', 1),
#  (2011, 3, 'FRAUD-IDENTITY THEFT', 1),
#  (2015, 2, 'DRIVE-BY', 1),
#  (2014, 4, 'FORGERY-OTH', 1),
#  (2014, 6, 'THEFT-LICENSE PLATE', 1),
#  (2014, 7, 'THEFT-BUILDING', 1),
#  (2015, 6, 'ROBBERY-BUSINESS-GUN', 1),
#  (2014, 4, 'PROPERTY LOST - POLICE EQUIPME', 1),
#  (2014, 11, 'BURGLARY-FORCE-RES', 1),
#  (2015, 4, 'BIAS INCIDENT', 1),
#  (2012, 11, 'THEFT-OTH', 1),
#  (2012, 6, 'BURGLARY-NOFORCE-RES', 1),
#  (2015, 4, 'METRO TRANSIT - ON BUS, TUNNEL', 1),
#  (2015, 4, 'NARC-FORGERY-PRESCRIPTION', 1),
#  (2015, 2, 'PROSTITUTION LOITERING', 1),
#  (2013, 6, 'FRAUD-OTHER', 1),
#  (2014, 5, 'FRAUD-CREDIT CARD', 1),
#  (2010, 7, 'FRAUD-CHECK', 1),
#  (2015, 3, 'ROBBERY-RESIDENCE-WEAPON', 1),
#  (2015, 1, 'ROBBERY-RESIDENCE-WEAPON', 1),
#  (2014, 6, 'EMBEZZLE', 1),
#  (2015, 4, 'NARC-POSSESS-OTHER', 1),
#  (2014, 12, 'ASSLT-AGG-WEAPON', 1),
#  (2014, 9, 'THEFT-BOAT', 1),
#  (2014, 7, 'THEFT-CARPROWL', 1),
#  (2014, 11, 'THEFT-AUTOACC', 1),
#  (2014, 8, 'PROPERTY LOST', 1),
#  (2015, 6, 'INJURY - ACCIDENTAL', 1),
#  (2013, 10, 'THEFT-OTH', 1),
#  (2014, 9, 'THEFT-PKPOCKET', 1),
#  (2010, 11, 'FRAUD-IDENTITY THEFT', 1),
#  (2014, 3, 'THREATS-OTHER', 1),
#  (2015, 1, 'NARC-FOUND-PILL/TABLET', 1),
#  (2015, 2, 'DISORDERLY CONDUCT', 1),
#  (2014, 6, 'PROPERTY LOST', 1),
#  (2015, 3, 'PROSTITUTION LOITERING', 1),
#  (2015, 2, 'NARC-SELL-AMPHETAMINE', 1),
#  (2005, 3, 'FORGERY-CHECK', 1),
#  (2015, 6, 'ROBBERY-BANK-GUN', 1),
#  (2001, 8, 'PROPERTY LOST', 1),
#  (2015, 6, 'NARC-POSSESS-AMPHETAMINE', 1),
#  (2011, 10, 'FRAUD-IDENTITY THEFT', 1),
#  (2010, 6, 'THEFT-LICENSE PLATE', 1),
#  (2004, 7, 'FRAUD-IDENTITY THEFT', 1),
#  (2015, 4, 'HOMICIDE-PREMEDITATED-GUN', 1),
#  (1990, 5, 'HARASSMENT', 1),
#  (2014, 11, 'BURGLARY-NOFORCE-NONRES', 1),
#  (2015, 2, 'URINATING/DEFECATING-IN PUBLIC', 1),
#  (2015, 2, 'PROSTITUTION-ASSIST-PROMOTE', 1),
#  (2015, 2, '[INC - CASE DC USE ONLY]', 1),
#  (2015, 3, 'NARC-MANUFACTURE-OTHER', 1),
#  (2015, 6, 'ASSLT-AGG-POLICE-BODYFORCE', 1),
#  (2015, 5, 'NARC-POSSESS-PILL/TABLET', 1),
#  (2000, 1, 'FRAUD-CHECK', 1),
#  (2014, 2, 'PROSTITUTION-ASSIST-PROMOTE', 1),
#  (2012, 4, 'FRAUD-OTHER', 1),
#  (2015, 1, 'DISPUTE-CIVIL PROPERTY (AUTO)', 1),
#  (2005, 6, 'THEFT-OTH', 1),
#  (2014, 3, 'HARASSMENT', 1),
#  (2015, 2, 'LOITERING', 1),
#  (2012, 10, 'FRAUD-OTHER', 1),
#  (2015, 6, 'NARC-DRUG TRAFFIC LOITERING', 1),
#  (2013, 5, 'THEFT-LICENSE PLATE', 1),
#  (2013, 2, 'FRAUD-IDENTITY THEFT', 1),
#  (2015, 4, '[INC - CASE DC USE ONLY]', 1),
#  (2015, 5, 'NARC-POSSESS-MARIJU', 1),
#  (2015, 3, 'NARC-FOUND-PILL/TABLET', 1),
#  (2014, 11, 'PROPERTY DAMAGE-RESIDENTIAL', 1),
#  (2015, 4, 'NARC-FOUND-AMPHETAMINE', 1),
#  (2015, 2, 'NARC-POSSESS-AMPHETAMINE', 1),
#  (2007, 4, 'FRAUD-IDENTITY THEFT', 1),
#  (2013, 8, 'FRAUD-CREDIT CARD', 1),
#  (2013, 2, 'THEFT-BUILDING', 1),
#  (2009, 9, 'FRAUD-IDENTITY THEFT', 1),
#  (2011, 7, 'FRAUD-IDENTITY THEFT', 1),
#  (2014, 8, 'VEH-THEFT-AUTO', 1),
#  (2010, 1, 'THREATS-OTHER', 1),
#  (2014, 7, 'THEFT-LICENSE PLATE', 1),
#  (2009, 4, 'FRAUD-OTHER', 1),
#  (2015, 5, 'GAMBLE-BETTING', 1),
#  (2015, 5, 'NARC-FRAUD-PRESCRIPTION', 1),
#  (2015, 4, 'EXTORTION', 1),
#  (2014, 11, 'VEH-THEFT-TRAILER', 1),
#  (2011, 5, 'EMBEZZLE', 1),
#  (2014, 12, 'WARRARR-FELONY', 1),
#  (2014, 1, 'PROPERTY DAMAGE - GRAFFITI', 1),
#  (2014, 12, 'PROPERTY STOLEN-POSSESS', 1),
#  (2014, 3, 'EMBEZZLE', 1),
#  (2014, 2, 'THEFT-OTH', 1),
#  (2015, 4, 'NARC-FOUND-SYNTHETIC', 1),
#  (2014, 7, 'BURGLARY-NOFORCE-NONRES', 1),
#  (2014, 5, 'FRAUD-OTHER', 1),
#  (2013, 1, 'DISTURBANCE-OTH', 1),
#  (2014, 8, 'THEFT-MAIL', 1),
#  (2015, 6, 'NARC-FOUND-AMPHETAMINE', 1),
#  (2015, 5, 'FRAUD-WELFARE', 1),
#  (2014, 10, 'THEFT-MAIL', 1),
#  (2015, 2, 'NARC-FOUND-PILL/TABLET', 1),
#  (2014, 12, 'DISTURBANCE-OTH', 1),
#  (2015, 6, 'BIAS INCIDENT', 1),
#  (2015, 6, 'ROBBERY-BANK-BODYFORCE', 1),
#  (2014, 6, 'PROPERTY DAMAGE-NON RESIDENTIA', 1),
#  (2015, 1, 'DISORDERLY CONDUCT', 1),
#  (1999, 1, 'FRAUD-IDENTITY THEFT', 1),
#  (2015, 5, 'DRIVE-BY', 1),
#  (2014, 9, 'THEFT-LICENSE PLATE', 1),
#  (2014, 10, 'BURGLARY-NOFORCE-NONRES', 1),
#  (2013, 8, 'FRAUD-OTHER', 1),
#  (2014, 1, 'DISTURBANCE-OTH', 1),
#  (2014, 3, 'THEFT-CARPROWL', 1),
#  (2014, 12, 'FORGERY-CREDIT CARD', 1),
#  (2006, 1, 'FRAUD-IDENTITY THEFT', 1),
#  (2015, 6, 'EXTORTION', 1),
#  (2014, 11, 'THREATS-WEAPON', 1),
#  (2015, 1, 'PORNOGRAPHY-OBSCENE MATERIAL', 1),
#  (2010, 4, 'FRAUD-IDENTITY THEFT', 1),
#  (2014, 3, 'THEFT-OTH', 1),
#  (2015, 5, 'PROPERTY STOLEN-SELL', 1),
#  (2013, 3, 'BURGLARY-FORCE-NONRES', 1),
#  (2014, 4, 'THEFT-BICYCLE', 1),
#  (2014, 10, 'FRAUD-OTHER', 1),
#  (2015, 6, 'DISPUTE-CIVIL PROPERTY (AUTO)', 1),
#  (2015, 6, 'LIQUOR LAW VIOLATION', 1),
#  (2012, 4, 'FRAUD-IDENTITY THEFT', 1),
#  (2001, 6, 'FRAUD-IDENTITY THEFT', 1),
#  (2015, 3, 'WEAPON-SURRENDER-EXCLUDING FIR', 1),
#  (2015, 1, 'DUI-DRUGS', 1),
#  (2014, 4, 'FRAUD-CHECK', 1),
#  (2015, 2, 'FALSE REPORT', 1),
#  (2014, 5, 'VEH-THEFT-AUTO', 1),
#  (2014, 3, 'THEFT-BICYCLE', 1),
#  (2010, 5, 'FRAUD-OTHER', 1),
#  (2015, 1, 'NARC-FOUND-METH', 1),
#  (2014, 11, 'PROPERTY LOST', 1),
#  (2014, 1, 'HARASSMENT', 1),
#  (2013, 8, 'FRAUD-IDENTITY THEFT', 1),
#  (2010, 1, 'EMBEZZLE', 1),
#  (2014, 2, 'FRAUD-OTHER', 1),
#  (2014, 4, 'VEH-THEFT-AUTO', 1),
#  (2014, 5, 'THEFT-CARPROWL', 1),
#  (2014, 4, 'THEFT-LICENSE PLATE', 1),
#  (2005, 8, 'EMBEZZLE', 1),
#  (2014, 7, 'THEFT-AUTOACC', 1),
#  (2014, 5, 'PROPERTY LOST', 1),
#  (2015, 3, 'NARC-POSSESS-PRESCRIPTION', 1),
#  (2015, 2, 'DUI-DRUGS', 1),
#  (2015, 1, 'NARC-FOUND-HALLUCINOGEN', 1),
#  (2014, 11, 'EMBEZZLE', 1),
#  (2015, 3, 'ROBBERY-RESIDENCE-BODYFORCE', 1),
#  (2015, 6, 'URINATING/DEFECATING-IN PUBLIC', 1),
#  (2014, 6, 'THEFT-MAIL', 1),
#  (2015, 4, 'LOITERING', 1),
#  (2015, 5, 'ROBBERY-BUSINESS-GUN', 1),
#  (2015, 6, 'NARC-POSSESS-MARIJU', 1),
#  (2015, 6, 'NARC-FOUND-COCAINE', 1),
#  (2015, 3, 'BIAS INCIDENT', 1),
#  (2011, 6, 'FRAUD-IDENTITY THEFT', 1),
#  (2015, 6, 'NARC-POSSESS-PILL/TABLET', 1),
#  (2015, 6, 'NARC-SELL-MARIJU', 1),
#  (2014, 3, 'THEFT-LICENSE PLATE', 1),
#  (2014, 11, 'THEFT-BICYCLE', 1),
#  (2013, 1, 'PROPERTY LOST', 1),
#  (2014, 11, 'TRAFFIC', 1),
#  (2013, 4, 'THEFT OF SERVICES', 1),
#  (2012, 11, 'FRAUD-IDENTITY THEFT', 1),
#  (2015, 3, 'ANIMAL-CRUELTY', 1),
#  (2014, 10, 'BURGLARY-SECURE PARKING-RES', 1),
#  (2015, 5, 'NARC-SELL-METH', 1),
#  (2015, 4, 'MALICIOUS HARASSMENT', 1),
#  (2015, 6, 'HOMICIDE-NEG-MANS-BODYFORCE', 1),
#  (2015, 5, 'THEFT-COINOP', 1),
#  (2014, 9, 'PROPERTY FOUND', 1),
#  (2013, 10, 'FRAUD-IDENTITY THEFT', 1),
#  (2013, 11, 'THEFT-OTH', 1)]

# %%
# %sql SELECT count(*) FROM seattlecrimeincidents
# Out:
# 1 rows affected.
# [(30814,)]

# %% [markdown]
# ### A simple table:
#
# <br>
#
# | Offense type | Offense code | Date | Location |
# | ---- | ----- | ---- | ---- | ---- |
# |  <small>tresspass | <small>5700 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |
# |  <small>larceny-theft | <small>2300 | <small> 2015-02-21 08:24:21 | <small> 15XX Block of Aurora St |

# %% [markdown]
# ```SQL
# SELECT foo FROM bar
# ```

# %% [markdown]
# <br><br>
# <img src="images/earthLatLong.png" width = "400">
# <br><br><br><br>
# [source](https://coast.noaa.gov/digitalcoast/training/datums)

# %% [markdown]
# http://neon-workwithdata.github.io/NEON-R-Spatio-Temporal-Data-and-Management-Intro/

# %% [markdown]
# Anthony's temporary notes:
#
# * uniqueness and consistency
# * systematic treatment of NULL
# * normalization: each entity should only be fully enumerated in one table which recudes redundancy and improves efficiency
#
# * CODDS:
# * First normal form: no repeating groups (e.g. 2 dates in the date col): solve by putting into two separate rows
# * second NF: must satisfy 1st NF, no attribute can depend on subset of candidate key, e.g. crime type depends on crime action (diff cols that then need to be udpated each time). Solution is to put in separate tables.
#
# * SQL clauses
# * 1:1, 1:many, etc joins
# * list some common functions
# * ways which a DB "understands" different types, e.g. dates, and what can be done with that
# * then ways in which DB understands location

# %% [markdown]
# <img src="http://neon-workwithdata.github.io/NEON-R-Spatio-Temporal-Data-and-Management-Intro/images/dc-spatial-vector/pnt_line_poly.png" width = "500">
