# %% [markdown]
# <img src="http://escience.washington.edu/wp-content/uploads/2016/02/DataScienceForSocialGood.png" width = "550">
#
#
# ### SQL Tutorial
#
# #### Friday June 17, 9 am - 12 pm
#
# #### Instructors
# Valentina Staneva, Bill Howe, Anthony Arendt

# %% [markdown]
# #### 1) How many "TRESPASS" offenses occurred in total?
# <br>
# #### 2) What is the most common crime in the dataset, and in what year and month did these crimes occur?
# <br>
# #### 3) What is the most common crime within 5 km of my house?
# <br><br>
# <small>Data source: "SeattleCrimeIncidents.csv" or http://www.seattle.gov/seattle-police-department/crime-data/spd-data-sets

# %% [markdown]
# #### What is a database?
# * software system for capturing, storing and analyzing data
# * nearly all databases use the _relational_ data model

# %% [markdown]
# <img src='images/terminology.png' width = 900px>

# %% [markdown]
# #### Relational data model:
# * data are structured into row/column format
#
# | crimesID | Offense type | Offense code | Date | Location |
# | ---- | ---- | ----- | ---- | ---- | ---- |
# |  <small> 1 | <small>tresspass | <small>5700 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |
# |  <small> 2 | <small>larceny-theft | <small>2300 | <small> 2015-02-21 08:24:21 | <small> 15XX Block of Aurora St |

# %% [markdown]
# * each record has a unique identifier (primary key)

# %% [markdown]
# #### Relational data model:
# * uses Structured Query Language (SQL):

# %% [markdown]
# ```SQL
# CREATE TABLE seattlecrimesincidents
#     ("crimesID" int,
#      "Offense type" character
#      "Offense code" int
#      "Date" timestamp
#      "Location" character);
# ```

# %% [markdown]
# * populating the database records:
# ```SQL
# INSERT INTO seattlecrimeincidents VALUES
#
#     (1,'trespass', 5700,'2015-01-28 09:30:00','12XX Block of E Pike St'),
#
#     (2,'larceny-theft',2300, '2015-02-21 08:24:21','15XX Block of Aurora St');
# ```

# %% [markdown]
# | crimesID | Offense type | Offense code | Date | Location |
# | ---- | ---- | ----- | ---- | ---- | ---- |
# |  <small> 1 | <small>tresspass | <small>5700 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |
# |  <small> 2 | <small>larceny-theft | <small>2300 | <small> 2015-02-21 08:24:21 | <small> 15XX Block of Aurora St |

# %% [markdown]
# ### Data in each column must be of the same type
#
# #### SQL requires this so it knows how to operate on the data

# %% [markdown]
# Some common [data types](https://www.postgresql.org/docs/9.4/static/datatype.html):
# <br>
# <div class="TABLE">
#     <a name="DATATYPE-TABLE" id="DATATYPE-TABLE"></a>
#
# <small>
#     <table class="CALSTABLE" border="1">
#       <colgroup><col>
#       <col>
#       <col>
#
#       <thead>
#         <tr>
#           <th>Name</th>
#
#           <th>Aliases</th>
#
#           <th>Description</th>
#         </tr>
#       </thead>
#
#       <tbody>
#
#         <tr>
#           <td><tt class="TYPE">boolean</tt></td>
#
#           <td><tt class="TYPE">bool</tt></td>
#
#           <td>logical Boolean (true/false)</td>
#         </tr>
#
#         <tr>
#           <td><tt class="TYPE">character [(<tt class="REPLACEABLE c4">n</tt>)]</tt></td>
#
#           <td><tt class="TYPE">char [(<tt class="REPLACEABLE c4">n</tt>)]</tt></td>
#
#           <td>fixed-length character string</td>
#         </tr>
#
#         <tr>
#           <td><tt class="TYPE">date</tt></td>
#
#           <td>&nbsp;</td>
#
#           <td>calendar date (year, month, day)</td>
#         </tr>
#
#         <tr>
#           <td><tt class="TYPE">double precision</tt></td>
#
#           <td><tt class="TYPE">float8</tt></td>
#
#           <td>double precision floating-point number (8 bytes)</td>
#         </tr>
#
#         <tr>
#           <td><tt class="TYPE">integer</tt></td>
#
#           <td><tt class="TYPE">int</tt>, <tt class="TYPE">int4</tt></td>
#
#           <td>signed four-byte integer</td>
#         </tr>
#
#         <tr>
#           <td><tt class="TYPE">json</tt></td>
#
#           <td>&nbsp;</td>
#
#           <td>JSON data</td>
#         </tr>
#
#
#         <tr>
#           <td><tt class="TYPE">money</tt></td>
#
#           <td>&nbsp;</td>
#
#           <td>currency amount</td>
#         </tr>
#
#         <tr>
#           <td><tt class="TYPE">timestamp [(<tt class="REPLACEABLE c4">p</tt>)] [ without time zone
#           ]</tt></td>
#
#           <td>&nbsp;</td>
#
#           <td>date and time (no time zone)</td>
#         </tr>
#
#         <tr>
#           <td><tt class="TYPE">xml</tt></td>
#
#           <td>&nbsp;</td>
#
#           <td>XML data</td>
#         </tr>
#       </tbody>
#     </table>
#   </div>

# %% [markdown]
# * selecting data:
# ```SQL
# SELECT *
#    FROM seattlecrimeincidents
#    WHERE "Offense code" = 5700;
# ```

# %% [markdown]
# | crimesID | Offense type | Offense code | Date | Location |
# | ---- | ---- | ----- | ---- | ---- | ---- |
# |  <small> 1 | <small>tresspass | <small>5700 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |

# %% [markdown]
# ### Database rules:
#
# #### take the time to [normalize](https://en.wikipedia.org/wiki/Database_normalization) your tables to minimize redundancy

# %% [markdown]
# #### example: multiple offenses at the same time
#
# | crimesID | Offense type | Offense code | Date | Location |
# | ---- | ---- | ----- | ---- | ---- | ---- |
# |  <small> 1 | <small>tresspass or burglary | <small>5700 or 5710 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |
# |  <small> 2 | <small>larceny-theft | <small>2300 | <small> 2015-02-21 08:24:21 | <small> 15XX Block of Aurora St |

# %% [markdown]
# ####  INCORRECT: database will have problems searching these columns

# %% [markdown]
# #### solution: create another row
#
# | crimesID | Offense type | Offense code | Date | Location |
# | ---- | ---- | ----- | ---- | ---- | ---- |
# |  <small> 1 | <small>tresspass | <small>5700 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |
# |  <small> 2 | <small> burglary | <small> 5710 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |
# |  <small> 3 | <small>larceny-theft | <small>2300 | <small> 2015-02-21 08:24:21 | <small> 15XX Block of Aurora St |

# %% [markdown]
# ### NULL values
#
# * missing data are a common feature of many datasets
# * here the code for "tresspass" is not known so the data entry is "X"
#
# | crimesID | Offense type | Offense code | Date | Location |
# | ---- | ---- | ----- | ---- | ---- | ---- |
# |  <small> 1 | <small>tresspass | <small>X | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |
# |  <small> 2 | <small> burglary | <small> 5710 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |
# |  <small> 3 | <small>larceny-theft | <small>2300 | <small> 2015-02-21 08:24:21 | <small> 15XX Block of Aurora St |

# %% [markdown]
# #### NULL values
# * conventionally, some value is used to represent missing data (e.g. "X" or -9999)
# * relational databases introduced NULL values:
#     * NULL is a state representing a lack of a value
#     * NULL is not the same as zero!
#     * NULL values are ignored in SELECT statements

# %% [markdown]
# #### Joining Tables
# * well designed databases distribute data across multiple tables, for efficiency
# * then we can JOIN data between tables as needed

# %% [markdown]
# | crimesID |  Offense code | Date | Location |
# | ---- |  ----- | ---- | ---- | ---- |
# |  <small> 1 |<small>5700 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |
# |  <small> 1 |<small>5700 | <small> 2015-02-12 03:25:00 | <small> 1XX Block of Aloha St |
# |  <small> 2 | <small> 5710 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |
# |  <small> 3 | <small>2300 | <small> 2015-02-21 08:24:21 | <small> 15XX Block of Aurora St |
#
# <br>
#
# | typesID | Offense type | Offense code |
# | ---- | ---- | ----- | ---- | |
# |  <small> 1 | <small>tresspass | <small>5700 |
# |  <small> 2 | <small> burglary | <small> 5710 |
# |  <small> 3 | <small>larceny-theft | <small>2300 |

# %% [markdown]
# <img src = 'images/joinTables.png' width = 800px>

# %% [markdown]
# #### Data Analysis:
# * databases have powerful methods for analyzing data
# * one of the most common tasks: applying statistics across groups
# * SQL syntax: GROUP BY

# %% [markdown]
# | crimesID |  Offense code | Date | Location | Damage |
# | ---- |  ----- | ---- | ---- | ---- | ---- |
# |  <small> 1 |<small>5700 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |<small> \$1,220 |
# |  <small> 1 |<small>5700 | <small> 2015-02-12 03:25:00 | <small> 1XX Block of Aloha St |<small> \$11,420 |
# |  <small> 2 | <small> 5710 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |<small> \$5,389 |
# |  <small> 2 | <small> 5710 | <small> 2015-1-02 12:31:20 | <small> 12XX Block of E Pine St |<small> \$15,231 |
# |  <small> 3 | <small>2300 | <small> 2015-02-21 08:24:21 | <small> 15XX Block of Aurora St |<small> \$2,405 |

# %% [markdown]
# * data grouped by "Offense code":
#
# | crimesID |  Offense code | Date | Location | Damage |
# | ---- |  ----- | ---- | ---- | ---- | ---- |
# |  <small> 1 |<small>5700 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |<small> \$1,220 |
# |  <small> 2 |<small>5700 | <small> 2015-02-12 03:25:00 | <small> 1XX Block of Aloha St |<small> \$11,420 |
# |    |    |    |    |    |
# |  <small> 3 | <small> 5710 | <small> 2015-01-28 09:30:00 | <small> 12XX Block of E Pike St |<small> \$5,389 |
# |  <small> 4 | <small> 5710 | <small> 2015-1-02 12:31:20 | <small> 12XX Block of E Pine St |<small> \$15,231 |
# |    |    |    |    |    |
# |  <small> 5 | <small>2300 | <small> 2015-02-21 08:24:21 | <small> 15XX Block of Aurora St |<small> \$2,405 |

# %% [markdown]
# * result of SUM(Damage) over "Offense code" groups:
#
# | Offense code | totalDamage |
# |   ---- | ---- |
# |  <small>5700  |<small> \$12,640 |
# |  <small> 5710 |<small> \$20,620 |
# |  <small>2300  |<small> \$2,405 |

# %% [markdown]
# ### some considerations:

# %% [markdown]
# #### databases are extremely efficient and fast (if well designed)
# #### databases are everywhere - your phone, etc

# %% [markdown]
# #### Database Implementation:
#
# * there are many relational database software implementations:
#    * commercial: Oracle, Microsoft SQL Server, IBM DB2
#    * open source: MySQL, PostgreSQL

# %% [markdown]
# * regardless of the software:
#    * most databases are deployed on a server
#    * can deploy locally for testing

# %% [markdown]
# #### Database Interface:
#
# * all databases are accessed via a _connection string_:
#    * hostname, port, user, password

# %% [markdown]
# <img src='images/databaseDiagram.png' width = 800px>

# %% [markdown]
# # EXERCISE 1: 15-20 MINUTES

# %% [markdown]
# ### EXERCISE 1 DEBRIEF:
#
# * what did you learn?
# * what was challenging or surprised you?

# %% [markdown]
# ### Recall our second analysis question:
#
# * "What is the most common crime in the dataset, and in what year and month did these crimes occur?"

# %% [markdown]
# #### To solve this we need to learn more about GROUP BY and the "date" field

# %%
# %load_ext sql
# %sql postgresql://awsdssg:datascience2016@dssg2016.cel0foggtnsk.us-east-1.rds.amazonaws.com/dssg2016
# Out:
# 'Connected: awsdssg@dssg2016'

# %%
# %%sql
# SELECT "Offense Type", count(*) AS incident_count
# FROM seattlecrimeincidents
# GROUP BY "Offense Type"
# ORDER BY "incident_count" DESC;
# Out:
# 150 rows affected.
# [('THEFT-CARPROWL', 5334),
#  ('THEFT-OTH', 1828),
#  ('VEH-THEFT-AUTO', 1684),
#  ('PROPERTY DAMAGE-NON RESIDENTIA', 1412),
#  ('BURGLARY-FORCE-RES', 1361),
#  ('DISTURBANCE-OTH', 1356),
#  ('ASSLT-NONAGG', 1210),
#  ('THEFT-SHOPLIFT', 1209),
#  ('PROPERTY FOUND', 1063),
#  ('FRAUD-IDENTITY THEFT', 856),
#  ('BURGLARY-NOFORCE-RES', 844),
#  ('THEFT-BUILDING', 822),
#  ('THEFT-BICYCLE', 741),
#  ('TRESPASS', 710),
#  ('BURGLARY-FORCE-NONRES', 628),
#  ('BURGLARY-SECURE PARKING-RES', 555),
#  ('WARRARR-FELONY', 540),
#  ('FRAUD-CREDIT CARD', 516),
#  ('HARASSMENT', 420),
#  ('PROPERTY DAMAGE-RESIDENTIAL', 398),
#  ('WARRARR-MISDEMEANOR', 397),
#  ('PROPERTY DAMAGE - GRAFFITI', 375),
#  ('ASSLT-AGG-WEAPON', 366),
#  ('BURGLARY-NOFORCE-NONRES', 326),
#  ('THEFT-LICENSE PLATE', 305),
#  ('THREATS-OTHER', 303),
#  ('ROBBERY-STREET-BODYFORCE', 301),
#  ('TRAFFIC', 274),
#  ('FRAUD-OTHER', 226),
#  ('THEFT-MAIL', 204),
#  ('FRAUD-CHECK', 193),
#  ('THREATS-KILL', 180),
#  ('PROPERTY LOST', 175),
#  ('THEFT-AUTOACC', 166),
#  ('ROBBERY-BUSINESS-BODYFORCE', 148),
#  ('ASSLT-AGG-BODYFORCE', 126),
#  ('VEH-THEFT-TRUCK', 118),
#  ('THEFT OF SERVICES', 116),
#  ('COUNTERFEIT', 112),
#  ('VEH-THEFT-MTRCYCLE', 103),
#  ('VEH-RCVD-FOR OTHER AGENCY', 94),
#  ('DISPUTE-OTH', 93),
#  ('NARC-POSSESS-HEROIN', 93),
#  ('THEFT-PKPOCKET', 93),
#  ('PROPERTY STOLEN-POSSESS', 92),
#  ('PROSTITUTION', 90),
#  ('ASSLT-AGG-GUN', 83),
#  ('VIOL-COURT ORDER', 80),
#  ('PROSTITUTION PATRONIZING', 79),
#  ('NARC-POSSESS-COCAINE', 78),
#  ('WEAPON-POSSESSION', 78),
#  ('NARC-SELL-COCAINE', 77),
#  ('ROBBERY-STREET-GUN', 75),
#  ('THREATS-WEAPON', 75),
#  ('EMBEZZLE', 72),
#  ('ROBBERY-STREET-WEAPON', 68),
#  ('DISTURBANCE-NOISE', 64),
#  ('DISPUTE-CIVIL PROPERTY (NON AU', 59),
#  ('FRAUD-WIRE-ELECTRONIC', 50),
#  ('BURGLARY-SECURE PARKING-NONRES', 50),
#  ('WEAPON-DISCHARGE', 50),
#  ('ASSLT-NONAGG-POLICE', 48),
#  ('ROBBERY-BUSINESS-WEAPON', 46),
#  ('NARC-POSSESS-METH', 45),
#  ('OBSTRUCT', 41),
#  ('FORGERY-CHECK', 39),
#  ('PROP RECOVERED-OTHER AGENCY', 39),
#  ('WARRANT-FUGITIVE', 38),
#  ('ROBBERY-BUSINESS-GUN', 35),
#  ('THEFT-AUTO PARTS', 33),
#  ('ANIMAL-OTH', 31),
#  ('ANIMAL-BITE', 30),
#  ('NARC-FOUND-OTHER', 30),
#  ('NARC-EQUIPMENT/PARAPHENALIA', 29),
#  ('LIQUOR LAW VIOLATION', 29),
#  ('INJURY - OTHER', 28),
#  ('DUI-LIQUOR', 25),
#  ('FALSE REPORT', 23),
#  ('NARC-FOUND-MARIJU', 23),
#  ('WEAPON-UNLAWFUL USE', 21),
#  ('NARC-SELL-HEROIN', 21),
#  ('FRAUD-COMPUTER', 19),
#  ('NARC-FOUND-HEROIN', 19),
#  ('MALICIOUS HARASSMENT', 18),
#  ('THEFT-PRSNATCH', 17),
#  ('VEH-THEFT-TRAILER', 17),
#  ('RECKLESS BURNING', 17),
#  ('ILLEGAL DUMPING', 17),
#  ('NARC-SELL-METH', 17),
#  ('DISPUTE-CIVIL PROPERTY (AUTO)', 16),
#  ('NARC-POSSESS-AMPHETAMINE', 15),
#  ('NARC-DRUG TRAFFIC LOITERING', 15),
#  ('ASSLT-AGG-POLICE-WEAPON', 15),
#  ('ROBBERY-RESIDENCE-WEAPON', 14),
#  ('PROPERTY LOST - POLICE EQUIPME', 14),
#  ('NARC-FORGERY-PRESCRIPTION', 13),
#  ('ROBBERY-RESIDENCE-BODYFORCE', 13),
#  ('DISORDERLY CONDUCT', 13),
#  ('DRIVE-BY', 12),
#  ('NARC-FOUND-METH', 12),
#  ('INJURY - ACCIDENTAL', 11),
#  ('ROBBERY-RESIDENCE-GUN', 11),
#  ('NARC-SELL-MARIJU', 11),
#  ('NARC-POSSESS-MARIJU', 11),
#  ('ELUDING-FELONY FLIGHT', 11),
#  ('WEAPON-SURRENDER-EXCLUDING FIR', 10),
#  ('FORGERY-CREDIT CARD', 10),
#  ('FORGERY-OTH', 10),
#  ('THEFT-COINOP', 10),
#  ('ENDANGERMENT', 10),
#  ('PROPERTY STOLEN-TRAFFICKING', 9),
#  ('PROSTITUTION LOITERING', 9),
#  ('NARC-SELL-AMPHETAMINE', 9),
#  ('[INC - CASE DC USE ONLY]', 8),
#  ('EXTORTION', 8),
#  ('BIAS INCIDENT', 8),
#  ('NARC-FRAUD-PRESCRIPTION', 7),
#  ('THEFT-BOAT', 7),
#  ('ASSLT-AGG-POLICE-BODYFORCE', 7),
#  ('URINATING/DEFECATING-IN PUBLIC', 7),
#  ('PROSTITUTION-ASSIST-PROMOTE', 7),
#  ('NARC-FOUND-COCAINE', 7),
#  ('NARC-POSSESS-OTHER', 6),
#  ('ANIMAL-CRUELTY', 6),
#  ('NARC-FOUND-PILL/TABLET', 5),
#  ('NARC-POSSESS-PILL/TABLET', 4),
#  ('ROBBERY-BANK-BODYFORCE', 4),
#  ('WEAPON-CONCEALED', 4),
#  ('PORNOGRAPHY-OBSCENE MATERIAL', 4),
#  ('HOMICIDE-PREMEDITATED-GUN', 4),
#  ('NARC-FOUND-AMPHETAMINE', 4),
#  ('FIREWORK-USE', 3),
#  ('PROPERTY STOLEN-SELL', 3),
#  ('NARC-POSSESS-PRESCRIPTION', 3),
#  ('LOITERING', 2),
#  ('NARC-PRODUCE-MARIJU', 2),
#  ('ESCAPE', 2),
#  ('NARC-SELL-OTHER', 2),
#  ('DUI-DRUGS', 2),
#  ('HOMICIDE-PREMEDITATED-BODYFORC', 2),
#  ('ROBBERY-BANK-GUN', 2),
#  ('NARC-MANUFACTURE-OTHER', 2),
#  ('HOMICIDE-PREMEDITATED-WEAPON', 2),
#  ('NARC-FOUND-SYNTHETIC', 1),
#  ('FRAUD-WELFARE', 1),
#  ('GAMBLE-BETTING', 1),
#  ('NARC-FOUND-HALLUCINOGEN', 1),
#  ('METRO TRANSIT - ON BUS, TUNNEL', 1),
#  ('PROPERTY RECOVERED - POLICE EQ', 1),
#  ('HOMICIDE-NEG-MANS-BODYFORCE', 1)]

# %%
# %%sql
# SELECT "Offense Type", "Year", "Month", count(*) AS incident_count
# FROM seattlecrimeincidents
# GROUP BY "Offense Type", "Year", "Month"
# ORDER BY "incident_count" DESC;
# Out:
# 968 rows affected.
# [('THEFT-CARPROWL', 2015, 1, 1163),
#  ('THEFT-CARPROWL', 2015, 5, 949),
#  ('THEFT-CARPROWL', 2015, 4, 829),
#  ('THEFT-CARPROWL', 2015, 3, 800),
#  ('THEFT-CARPROWL', 2015, 2, 783),
#  ('THEFT-CARPROWL', 2015, 6, 734),
#  ('VEH-THEFT-AUTO', 2015, 1, 422),
#  ('THEFT-OTH', 2015, 1, 390),
#  ('BURGLARY-FORCE-RES', 2015, 1, 316),
#  ('THEFT-OTH', 2015, 3, 300),
#  ('THEFT-OTH', 2015, 5, 291),
#  ('PROPERTY DAMAGE-NON RESIDENTIA', 2015, 1, 285),
#  ('VEH-THEFT-AUTO', 2015, 3, 281),
#  ('VEH-THEFT-AUTO', 2015, 4, 280),
#  ('THEFT-OTH', 2015, 4, 279),
#  ('DISTURBANCE-OTH', 2015, 5, 277),
#  ('THEFT-OTH', 2015, 6, 274),
#  ('THEFT-SHOPLIFT', 2015, 1, 247),
#  ('PROPERTY DAMAGE-NON RESIDENTIA', 2015, 4, 244),
#  ('DISTURBANCE-OTH', 2015, 1, 242),
#  ('VEH-THEFT-AUTO', 2015, 2, 242),
#  ('BURGLARY-FORCE-RES', 2015, 5, 238),
#  ('PROPERTY DAMAGE-NON RESIDENTIA', 2015, 3, 237),
#  ('DISTURBANCE-OTH', 2015, 6, 237),
#  ('ASSLT-NONAGG', 2015, 5, 235),
#  ('PROPERTY DAMAGE-NON RESIDENTIA', 2015, 5, 235),
#  ('THEFT-OTH', 2015, 2, 219),
#  ('VEH-THEFT-AUTO', 2015, 5, 218),
#  ('BURGLARY-FORCE-RES', 2015, 3, 217),
#  ('THEFT-SHOPLIFT', 2015, 3, 217),
#  ('DISTURBANCE-OTH', 2015, 4, 215),
#  ('FRAUD-IDENTITY THEFT', 2015, 4, 210),
#  ('VEH-THEFT-AUTO', 2015, 6, 210),
#  ('PROPERTY FOUND', 2015, 1, 209),
#  ('ASSLT-NONAGG', 2015, 1, 209),
#  ('BURGLARY-FORCE-RES', 2015, 4, 206),
#  ('PROPERTY DAMAGE-NON RESIDENTIA', 2015, 6, 204),
#  ('DISTURBANCE-OTH', 2015, 3, 201),
#  ('PROPERTY FOUND', 2015, 3, 198),
#  ('ASSLT-NONAGG', 2015, 4, 196),
#  ('THEFT-SHOPLIFT', 2015, 5, 196),
#  ('PROPERTY DAMAGE-NON RESIDENTIA', 2015, 2, 195),
#  ('THEFT-SHOPLIFT', 2015, 4, 191),
#  ('ASSLT-NONAGG', 2015, 3, 190),
#  ('ASSLT-NONAGG', 2015, 6, 189),
#  ('THEFT-SHOPLIFT', 2015, 2, 187),
#  ('ASSLT-NONAGG', 2015, 2, 186),
#  ('BURGLARY-FORCE-RES', 2015, 2, 186),
#  ('DISTURBANCE-OTH', 2015, 2, 181),
#  ('PROPERTY FOUND', 2015, 5, 181),
#  ('THEFT-BICYCLE', 2015, 5, 180),
#  ('BURGLARY-FORCE-RES', 2015, 6, 173),
#  ('PROPERTY FOUND', 2015, 4, 172),
#  ('FRAUD-IDENTITY THEFT', 2015, 3, 172),
#  ('THEFT-SHOPLIFT', 2015, 6, 168),
#  ('PROPERTY FOUND', 2015, 6, 160),
#  ('BURGLARY-NOFORCE-RES', 2015, 1, 160),
#  ('THEFT-BUILDING', 2015, 3, 155),
#  ('THEFT-BUILDING', 2015, 1, 154),
#  ('BURGLARY-NOFORCE-RES', 2015, 5, 150),
#  ('BURGLARY-NOFORCE-RES', 2015, 4, 145),
#  ('THEFT-BUILDING', 2015, 2, 142),
#  ('BURGLARY-NOFORCE-RES', 2015, 3, 134),
#  ('PROPERTY FOUND', 2015, 2, 134),
#  ('TRESPASS', 2015, 1, 134),
#  ('WARRARR-FELONY', 2015, 1, 131),
#  ('BURGLARY-FORCE-NONRES', 2015, 1, 130),
#  ('THEFT-BUILDING', 2015, 5, 129),
#  ('THEFT-BICYCLE', 2015, 6, 128),
#  ('BURGLARY-NOFORCE-RES', 2015, 6, 127),
#  ('TRESPASS', 2015, 3, 125),
#  ('FRAUD-IDENTITY THEFT', 2015, 2, 125),
#  ('BURGLARY-FORCE-NONRES', 2015, 5, 122),
#  ('TRESPASS', 2015, 4, 121),
#  ('BURGLARY-FORCE-NONRES', 2015, 3, 118),
#  ('TRESPASS', 2015, 5, 117),
#  ('THEFT-BICYCLE', 2015, 4, 117),
#  ('TRESPASS', 2015, 6, 114),
#  ('THEFT-BUILDING', 2015, 4, 109),
#  ('BURGLARY-SECURE PARKING-RES', 2015, 5, 104),
#  ('BURGLARY-SECURE PARKING-RES', 2015, 4, 104),
#  ('FRAUD-IDENTITY THEFT', 2015, 1, 103),
#  ('THEFT-BUILDING', 2015, 6, 103),
#  ('THEFT-BICYCLE', 2015, 3, 102),
#  ('THEFT-BICYCLE', 2015, 2, 101),
#  ('BURGLARY-NOFORCE-RES', 2015, 2, 99),
#  ('TRESPASS', 2015, 2, 99),
#  ('WARRARR-MISDEMEANOR', 2015, 1, 97),
#  ('FRAUD-CREDIT CARD', 2015, 5, 97),
#  ('BURGLARY-SECURE PARKING-RES', 2015, 3, 97),
#  ('WARRARR-FELONY', 2015, 6, 96),
#  ('FRAUD-CREDIT CARD', 2015, 4, 95),
#  ('BURGLARY-SECURE PARKING-RES', 2015, 6, 94),
#  ('BURGLARY-FORCE-NONRES', 2015, 4, 94),
#  ('WARRARR-FELONY', 2015, 5, 93),
#  ('THEFT-BICYCLE', 2015, 1, 92),
#  ('BURGLARY-FORCE-NONRES', 2015, 2, 89),
#  ('BURGLARY-SECURE PARKING-RES', 2015, 1, 79),
#  ('HARASSMENT', 2015, 5, 77),
#  ('WARRARR-FELONY', 2015, 4, 77),
#  ('FRAUD-CREDIT CARD', 2015, 1, 75),
#  ('PROPERTY DAMAGE - GRAFFITI', 2015, 1, 75),
#  ('PROPERTY DAMAGE-RESIDENTIAL', 2015, 1, 74),
#  ('FRAUD-CREDIT CARD', 2015, 6, 74),
#  ('WARRARR-FELONY', 2015, 3, 73),
#  ('ASSLT-AGG-WEAPON', 2015, 1, 73),
#  ('HARASSMENT', 2015, 4, 72),
#  ('PROPERTY DAMAGE-RESIDENTIAL', 2015, 4, 71),
#  ('FRAUD-CREDIT CARD', 2015, 2, 70),
#  ('WARRARR-FELONY', 2015, 2, 69),
#  ('PROPERTY DAMAGE - GRAFFITI', 2015, 5, 69),
#  ('WARRARR-MISDEMEANOR', 2015, 4, 69),
#  ('FRAUD-OTHER', 2015, 1, 68),
#  ('PROPERTY DAMAGE-RESIDENTIAL', 2015, 5, 68),
#  ('BURGLARY-SECURE PARKING-RES', 2015, 2, 66),
#  ('ASSLT-AGG-WEAPON', 2015, 6, 66),
#  ('HARASSMENT', 2015, 2, 66),
#  ('HARASSMENT', 2015, 1, 65),
#  ('ASSLT-AGG-WEAPON', 2015, 5, 65),
#  ('BURGLARY-NOFORCE-NONRES', 2015, 1, 65),
#  ('WARRARR-MISDEMEANOR', 2015, 3, 65),
#  ('ROBBERY-STREET-BODYFORCE', 2015, 1, 65),
#  ('PROPERTY DAMAGE - GRAFFITI', 2015, 2, 65),
#  ('BURGLARY-FORCE-NONRES', 2015, 6, 64),
#  ('FRAUD-IDENTITY THEFT', 2015, 5, 64),
#  ('PROPERTY DAMAGE - GRAFFITI', 2015, 3, 64),
#  ('PROPERTY DAMAGE-RESIDENTIAL', 2015, 2, 61),
#  ('THEFT-LICENSE PLATE', 2015, 1, 60),
#  ('FRAUD-CREDIT CARD', 2015, 3, 60),
#  ('HARASSMENT', 2015, 6, 60),
#  ('THREATS-OTHER', 2015, 5, 59),
#  ('WARRARR-MISDEMEANOR', 2015, 5, 59),
#  ('THEFT-LICENSE PLATE', 2015, 3, 59),
#  ('PROPERTY DAMAGE-RESIDENTIAL', 2015, 3, 59),
#  ('PROPERTY DAMAGE-RESIDENTIAL', 2015, 6, 58),
#  ('BURGLARY-NOFORCE-NONRES', 2015, 3, 58),
#  ('HARASSMENT', 2015, 3, 58),
#  ('ASSLT-AGG-WEAPON', 2015, 3, 57),
#  ('ASSLT-AGG-WEAPON', 2015, 2, 57),
#  ('TRAFFIC', 2015, 1, 56),
#  ('BURGLARY-NOFORCE-NONRES', 2015, 6, 54),
#  ('PROSTITUTION PATRONIZING', 2015, 1, 54),
#  ('WARRARR-MISDEMEANOR', 2015, 2, 54),
#  ('WARRARR-MISDEMEANOR', 2015, 6, 53),
#  ('THREATS-OTHER', 2015, 3, 53),
#  ('BURGLARY-NOFORCE-NONRES', 2015, 5, 52),
#  ('ROBBERY-STREET-BODYFORCE', 2015, 5, 52),
#  ('THEFT-CARPROWL', 2014, 12, 52),
#  ('ROBBERY-STREET-BODYFORCE', 2015, 3, 52),
#  ('THREATS-OTHER', 2015, 4, 52),
#  ('THREATS-OTHER', 2015, 1, 51),
#  ('TRAFFIC', 2015, 6, 51),
#  ('ROBBERY-BUSINESS-BODYFORCE', 2015, 1, 51),
#  ('BURGLARY-NOFORCE-NONRES', 2015, 2, 49),
#  ('ROBBERY-STREET-BODYFORCE', 2015, 6, 49),
#  ('PROPERTY DAMAGE - GRAFFITI', 2015, 4, 48),
#  ('ROBBERY-STREET-BODYFORCE', 2015, 4, 48),
#  ('THEFT-MAIL', 2015, 1, 48),
#  ('PROPERTY DAMAGE - GRAFFITI', 2015, 6, 48),
#  ('ASSLT-AGG-WEAPON', 2015, 4, 47),
#  ('TRAFFIC', 2015, 5, 46),
#  ('THREATS-OTHER', 2015, 6, 46),
#  ('THREATS-KILL', 2015, 1, 46),
#  ('TRAFFIC', 2015, 3, 45),
#  ('BURGLARY-NOFORCE-NONRES', 2015, 4, 42),
#  ('THEFT-LICENSE PLATE', 2015, 4, 42),
#  ('THEFT-LICENSE PLATE', 2015, 2, 41),
#  ('VEH-THEFT-TRUCK', 2015, 1, 40),
#  ('THREATS-OTHER', 2015, 2, 40),
#  ('THEFT-AUTOACC', 2015, 3, 40),
#  ('FRAUD-IDENTITY THEFT', 2015, 6, 39),
#  ('TRAFFIC', 2015, 2, 39),
#  ('THEFT-LICENSE PLATE', 2015, 6, 39),
#  ('THEFT-LICENSE PLATE', 2015, 5, 39),
#  ('THEFT-OTH', 2014, 12, 38),
#  ('PROPERTY LOST', 2015, 1, 38),
#  ('TRAFFIC', 2015, 4, 36),
#  ('THEFT-AUTOACC', 2015, 1, 35),
#  ('FRAUD-CHECK', 2015, 1, 35),
#  ('ROBBERY-STREET-BODYFORCE', 2015, 2, 35),
#  ('COUNTERFEIT', 2015, 4, 34),
#  ('THEFT-MAIL', 2015, 2, 33),
#  ('THEFT-AUTOACC', 2015, 2, 33),
#  ('FRAUD-OTHER', 2015, 5, 32),
#  ('THEFT-MAIL', 2015, 4, 32),
#  ('THEFT OF SERVICES', 2015, 1, 32),
#  ('FRAUD-OTHER', 2015, 2, 31),
#  ('THEFT-MAIL', 2015, 3, 31),
#  ('FRAUD-OTHER', 2015, 3, 31),
#  ('FRAUD-IDENTITY THEFT', 2014, 12, 31),
#  ('ASSLT-AGG-GUN', 2015, 1, 29),
#  ('DISPUTE-OTH', 2015, 1, 28),
#  ('THREATS-KILL', 2015, 3, 28),
#  ('FRAUD-CHECK', 2015, 2, 28),
#  ('PROPERTY LOST', 2015, 3, 28),
#  ('THREATS-KILL', 2015, 5, 28),
#  ('FRAUD-CHECK', 2015, 5, 27),
#  ('THREATS-KILL', 2015, 4, 27),
#  ('PROPERTY LOST', 2015, 6, 27),
#  ('THREATS-KILL', 2015, 2, 27),
#  ('VEH-THEFT-AUTO', 2014, 12, 26),
#  ('FRAUD-CHECK', 2015, 4, 26),
#  ('ROBBERY-BUSINESS-BODYFORCE', 2015, 3, 25),
#  ('PROPERTY STOLEN-POSSESS', 2015, 2, 24),
#  ('FRAUD-CHECK', 2015, 3, 24),
#  ('THEFT-MAIL', 2015, 5, 24),
#  ('THREATS-KILL', 2015, 6, 24),
#  ('ASSLT-AGG-BODYFORCE', 2015, 2, 23),
#  ('PROPERTY LOST', 2015, 2, 23),
#  ('DISPUTE-OTH', 2015, 5, 23),
#  ('ASSLT-AGG-BODYFORCE', 2015, 5, 23),
#  ('PROSTITUTION', 2015, 4, 23),
#  ('PROSTITUTION', 2015, 6, 23),
#  ('ASSLT-AGG-BODYFORCE', 2015, 6, 23),
#  ('THEFT-PKPOCKET', 2015, 1, 22),
#  ('BURGLARY-FORCE-RES', 2014, 12, 22),
#  ('NARC-POSSESS-HEROIN', 2015, 2, 22),
#  ('ROBBERY-BUSINESS-BODYFORCE', 2015, 2, 22),
#  ('VEH-THEFT-MTRCYCLE', 2015, 1, 22),
#  ('VEH-THEFT-MTRCYCLE', 2015, 5, 22),
#  ('PROSTITUTION', 2015, 5, 21),
#  ('THEFT-PKPOCKET', 2015, 2, 21),
#  ('THEFT-AUTOACC', 2015, 5, 21),
#  ('FRAUD-OTHER', 2015, 4, 21),
#  ('ASSLT-AGG-BODYFORCE', 2015, 1, 21),
#  ('ASSLT-NONAGG-POLICE', 2015, 1, 20),
#  ('THEFT OF SERVICES', 2015, 5, 20),
#  ('NARC-POSSESS-HEROIN', 2015, 3, 20),
#  ('VEH-RCVD-FOR OTHER AGENCY', 2015, 3, 20),
#  ('FRAUD-CREDIT CARD', 2014, 11, 20),
#  ('THEFT OF SERVICES', 2015, 4, 20),
#  ('PROPERTY LOST', 2015, 5, 20),
#  ('THEFT-AUTOACC', 2015, 4, 20),
#  ('VEH-THEFT-MTRCYCLE', 2015, 6, 20),
#  ('NARC-POSSESS-COCAINE', 2015, 2, 20),
#  ('COUNTERFEIT', 2015, 1, 19),
#  ('FRAUD-CHECK', 2015, 6, 19),
#  ('VEH-THEFT-TRUCK', 2015, 3, 19),
#  ('PROPERTY LOST', 2015, 4, 19),
#  ('ASSLT-AGG-BODYFORCE', 2015, 3, 19),
#  ('VIOL-COURT ORDER', 2015, 6, 19),
#  ('WEAPON-POSSESSION', 2015, 1, 19),
#  ('VEH-THEFT-TRUCK', 2015, 5, 18),
#  ('ROBBERY-BUSINESS-BODYFORCE', 2015, 5, 18),
#  ('VEH-RCVD-FOR OTHER AGENCY', 2015, 1, 18),
#  ('COUNTERFEIT', 2015, 3, 18),
#  ('VEH-THEFT-MTRCYCLE', 2015, 3, 18),
#  ('THEFT-PKPOCKET', 2015, 4, 17),
#  ('THEFT-MAIL', 2014, 12, 17),
#  ('NARC-POSSESS-HEROIN', 2015, 1, 17),
#  ('ROBBERY-STREET-WEAPON', 2015, 2, 17),
#  ('ASSLT-AGG-BODYFORCE', 2015, 4, 17),
#  ('ROBBERY-BUSINESS-BODYFORCE', 2015, 4, 17),
#  ('DISPUTE-CIVIL PROPERTY (NON AU', 2015, 3, 17),
#  ('THEFT OF SERVICES', 2015, 6, 17),
#  ('WARRANT-FUGITIVE', 2015, 1, 17),
#  ('BURGLARY-NOFORCE-RES', 2014, 12, 17),
#  ('NARC-SELL-COCAINE', 2015, 1, 17),
#  ('ASSLT-AGG-GUN', 2015, 2, 17),
#  ('ROBBERY-STREET-WEAPON', 2015, 6, 16),
#  ('WEAPON-POSSESSION', 2015, 3, 16),
#  ('COUNTERFEIT', 2015, 2, 16),
#  ('NARC-POSSESS-HEROIN', 2015, 4, 16),
#  ('THREATS-WEAPON', 2015, 2, 16),
#  ('VEH-THEFT-TRUCK', 2015, 2, 16),
#  ('ROBBERY-STREET-GUN', 2015, 1, 16),
#  ('THREATS-WEAPON', 2015, 3, 16),
#  ('NARC-POSSESS-COCAINE', 2015, 1, 16),
#  ('DISPUTE-CIVIL PROPERTY (NON AU', 2015, 5, 16),
#  ('ROBBERY-STREET-GUN', 2015, 5, 16),
#  ('THEFT OF SERVICES', 2015, 3, 15),
#  ('PROPERTY STOLEN-POSSESS', 2015, 1, 15),
#  ('WEAPON-DISCHARGE', 2015, 2, 15),
#  ('NARC-SELL-COCAINE', 2015, 5, 15),
#  ('COUNTERFEIT', 2015, 5, 15),
#  ('DISTURBANCE-NOISE', 2015, 1, 15),
#  ('ROBBERY-BUSINESS-BODYFORCE', 2015, 6, 15),
#  ('THREATS-WEAPON', 2015, 1, 15),
#  ('FRAUD-WIRE-ELECTRONIC', 2015, 1, 15),
#  ('FRAUD-CREDIT CARD', 2014, 12, 15),
#  ('PROPERTY STOLEN-POSSESS', 2015, 5, 15),
#  ('THEFT-PKPOCKET', 2015, 5, 15),
#  ('VEH-RCVD-FOR OTHER AGENCY', 2015, 4, 15),
#  ('THEFT-BICYCLE', 2014, 12, 15),
#  ('NARC-POSSESS-COCAINE', 2015, 5, 14),
#  ('VIOL-COURT ORDER', 2015, 1, 14),
#  ('NARC-SELL-COCAINE', 2015, 2, 14),
#  ('DISPUTE-OTH', 2015, 2, 14),
#  ('PROPERTY STOLEN-POSSESS', 2015, 3, 14),
#  ('VEH-RCVD-FOR OTHER AGENCY', 2015, 5, 14),
#  ('FRAUD-CHECK', 2014, 12, 14),
#  ('VEH-RCVD-FOR OTHER AGENCY', 2015, 6, 14),
#  ('NARC-POSSESS-METH', 2015, 1, 14),
#  ('ROBBERY-STREET-GUN', 2015, 3, 13),
#  ('VEH-RCVD-FOR OTHER AGENCY', 2015, 2, 13),
#  ('DISTURBANCE-NOISE', 2015, 5, 13),
#  ('ROBBERY-STREET-GUN', 2015, 2, 13),
#  ('NARC-SELL-COCAINE', 2015, 6, 13),
#  ('WEAPON-POSSESSION', 2015, 6, 13),
#  ('ROBBERY-BUSINESS-WEAPON', 2015, 3, 13),
#  ('FRAUD-OTHER', 2015, 6, 13),
#  ('BURGLARY-SECURE PARKING-NONRES', 2015, 3, 13),
#  ('VEH-THEFT-MTRCYCLE', 2015, 4, 13),
#  ('VIOL-COURT ORDER', 2015, 4, 12),
#  ('ASSLT-AGG-GUN', 2015, 4, 12),
#  ('THEFT-AUTO PARTS', 2015, 1, 12),
#  ('BURGLARY-SECURE PARKING-NONRES', 2015, 4, 12),
#  ('VIOL-COURT ORDER', 2015, 3, 12),
#  ('FRAUD-IDENTITY THEFT', 2014, 11, 12),
#  ('PROPERTY STOLEN-POSSESS', 2015, 4, 12),
#  ('VEH-THEFT-TRUCK', 2015, 4, 12),
#  ('DISPUTE-OTH', 2015, 6, 12),
#  ('WEAPON-POSSESSION', 2015, 4, 12),
#  ('LIQUOR LAW VIOLATION', 2015, 5, 12),
#  ('ROBBERY-STREET-WEAPON', 2015, 4, 12),
#  ('THEFT-LICENSE PLATE', 2014, 12, 12),
#  ('VIOL-COURT ORDER', 2015, 2, 12),
#  ('ROBBERY-STREET-WEAPON', 2015, 3, 11),
#  ('WEAPON-DISCHARGE', 2015, 4, 11),
#  ('ROBBERY-STREET-GUN', 2015, 6, 11),
#  ('THEFT OF SERVICES', 2015, 2, 11),
#  ('THEFT-AUTOACC', 2015, 6, 11),
#  ('VEH-THEFT-TRUCK', 2015, 6, 11),
#  ('WEAPON-POSSESSION', 2015, 5, 11),
#  ('PROPERTY STOLEN-POSSESS', 2015, 6, 11),
#  ('THEFT-MAIL', 2015, 6, 11),
#  ('DISTURBANCE-NOISE', 2015, 6, 11),
#  ('NARC-POSSESS-COCAINE', 2015, 3, 11),
#  ('ROBBERY-BUSINESS-WEAPON', 2015, 1, 11),
#  ('THREATS-WEAPON', 2015, 5, 11),
#  ('PROPERTY DAMAGE-NON RESIDENTIA', 2014, 12, 11),
#  ('ASSLT-AGG-GUN', 2015, 6, 11),
#  ('THEFT-PKPOCKET', 2015, 6, 11),
#  ('WEAPON-DISCHARGE', 2015, 1, 10),
#  ('NARC-POSSESS-COCAINE', 2015, 6, 10),
#  ('NARC-SELL-COCAINE', 2015, 3, 10),
#  ('PROSTITUTION', 2015, 2, 10),
#  ('PROSTITUTION', 2015, 1, 10),
#  ('PROP RECOVERED-OTHER AGENCY', 2015, 1, 10),
#  ('EMBEZZLE', 2015, 4, 10),
#  ('ROBBERY-BUSINESS-GUN', 2015, 4, 10),
#  ('DISTURBANCE-NOISE', 2015, 2, 10),
#  ('DISTURBANCE-NOISE', 2015, 3, 10),
#  ('FRAUD-OTHER', 2014, 12, 10),
#  ('FRAUD-IDENTITY THEFT', 2014, 10, 10),
#  ('ROBBERY-BUSINESS-GUN', 2015, 3, 10),
#  ('DISPUTE-OTH', 2015, 4, 9),
#  ('FRAUD-WIRE-ELECTRONIC', 2015, 2, 9),
#  ('THREATS-WEAPON', 2015, 6, 9),
#  ('HARASSMENT', 2014, 12, 9),
#  ('NARC-POSSESS-METH', 2015, 2, 9),
#  ('NARC-FOUND-MARIJU', 2015, 4, 9),
#  ('PROP RECOVERED-OTHER AGENCY', 2015, 6, 9),
#  ('EMBEZZLE', 2015, 5, 9),
#  ('EMBEZZLE', 2015, 1, 9),
#  ('THEFT-BUILDING', 2014, 12, 9),
#  ('EMBEZZLE', 2015, 6, 9),
#  ('THEFT-OTH', 2014, 6, 9),
#  ('THEFT-OTH', 2014, 11, 9),
#  ('FRAUD-IDENTITY THEFT', 2014, 1, 9),
#  ('FRAUD-IDENTITY THEFT', 2014, 5, 9),
#  ('INJURY - OTHER', 2015, 6, 9),
#  ('NARC-SELL-METH', 2015, 1, 8),
#  ('NARC-SELL-COCAINE', 2015, 4, 8),
#  ('FRAUD-WIRE-ELECTRONIC', 2015, 3, 8),
#  ('ASSLT-AGG-GUN', 2015, 5, 8),
#  ('OBSTRUCT', 2015, 1, 8),
#  ('ROBBERY-BUSINESS-GUN', 2015, 2, 8),
#  ('NARC-POSSESS-HEROIN', 2015, 6, 8),
#  ('FALSE REPORT', 2015, 4, 8),
#  ('EMBEZZLE', 2015, 3, 8),
#  ('FRAUD-WIRE-ELECTRONIC', 2015, 4, 8),
#  ('OBSTRUCT', 2015, 5, 8),
#  ('VIOL-COURT ORDER', 2015, 5, 8),
#  ('NARC-POSSESS-HEROIN', 2015, 5, 8),
#  ('PROP RECOVERED-OTHER AGENCY', 2015, 5, 8),
#  ('MALICIOUS HARASSMENT', 2015, 5, 8),
#  ('ASSLT-NONAGG-POLICE', 2015, 2, 8),
#  ('LIQUOR LAW VIOLATION', 2015, 1, 7),
#  ('PROSTITUTION PATRONIZING', 2015, 5, 7),
#  ('PROSTITUTION PATRONIZING', 2015, 6, 7),
#  ('WARRANT-FUGITIVE', 2015, 2, 7),
#  ('ANIMAL-BITE', 2015, 5, 7),
#  ('BURGLARY-SECURE PARKING-NONRES', 2015, 6, 7),
#  ('FALSE REPORT', 2015, 1, 7),
#  ('NARC-POSSESS-COCAINE', 2015, 4, 7),
#  ('RECKLESS BURNING', 2015, 1, 7),
#  ('PROPERTY FOUND', 2014, 12, 7),
#  ('EMBEZZLE', 2015, 2, 7),
#  ('ANIMAL-BITE', 2015, 6, 7),
#  ('OBSTRUCT', 2015, 3, 7),
#  ('NARC-POSSESS-METH', 2015, 6, 7),
#  ('ROBBERY-BUSINESS-WEAPON', 2015, 5, 7),
#  ('FRAUD-CHECK', 2014, 11, 7),
#  ('THEFT-CARPROWL', 2014, 11, 7),
#  ('PROPERTY LOST', 2014, 12, 7),
#  ('FRAUD-IDENTITY THEFT', 2014, 4, 7),
#  ('DUI-LIQUOR', 2015, 1, 7),
#  ('OBSTRUCT', 2015, 4, 7),
#  ('OBSTRUCT', 2015, 2, 7),
#  ('THREATS-WEAPON', 2015, 4, 7),
#  ('FORGERY-CHECK', 2015, 2, 7),
#  ('DISPUTE-OTH', 2015, 3, 7),
#  ('FORGERY-CHECK', 2014, 12, 7),
#  ('WEAPON-POSSESSION', 2015, 2, 7),
#  ('BURGLARY-SECURE PARKING-NONRES', 2015, 5, 7),
#  ('NARC-POSSESS-AMPHETAMINE', 2015, 4, 7),
#  ('NARC-POSSESS-METH', 2015, 4, 7),
#  ('DISPUTE-CIVIL PROPERTY (NON AU', 2015, 4, 7),
#  ('DISPUTE-CIVIL PROPERTY (NON AU', 2015, 6, 7),
#  ('PROSTITUTION PATRONIZING', 2015, 4, 7),
#  ('NARC-FOUND-OTHER', 2015, 1, 7),
#  ('NARC-EQUIPMENT/PARAPHENALIA', 2015, 4, 7),
#  ('ROBBERY-STREET-WEAPON', 2015, 1, 6),
#  ('NARC-FOUND-HEROIN', 2015, 6, 6),
#  ('ANIMAL-BITE', 2015, 1, 6),
#  ('THEFT-AUTO PARTS', 2015, 6, 6),
#  ('BURGLARY-SECURE PARKING-RES', 2014, 12, 6),
#  ('NARC-EQUIPMENT/PARAPHENALIA', 2015, 3, 6),
#  ('ROBBERY-STREET-WEAPON', 2015, 5, 6),
#  ('THEFT-PRSNATCH', 2015, 4, 6),
#  ('NARC-SELL-HEROIN', 2015, 5, 6),
#  ('THEFT-PKPOCKET', 2015, 3, 6),
#  ('ROBBERY-RESIDENCE-GUN', 2015, 3, 6),
#  ('FRAUD-COMPUTER', 2015, 1, 6),
#  ('ANIMAL-OTH', 2015, 1, 6),
#  ('ANIMAL-OTH', 2015, 5, 6),
#  ('NARC-FOUND-OTHER', 2015, 3, 6),
#  ('WEAPON-DISCHARGE', 2015, 5, 6),
#  ('WEAPON-UNLAWFUL USE', 2015, 5, 6),
#  ('ASSLT-NONAGG-POLICE', 2015, 3, 6),
#  ('ROBBERY-STREET-GUN', 2015, 4, 6),
#  ('ANIMAL-OTH', 2015, 6, 6),
#  ('NARC-POSSESS-METH', 2015, 3, 6),
#  ('VEH-THEFT-MTRCYCLE', 2015, 2, 6),
#  ('ASSLT-AGG-GUN', 2015, 3, 6),
#  ('BURGLARY-FORCE-NONRES', 2014, 12, 6),
#  ('BURGLARY-SECURE PARKING-NONRES', 2015, 2, 6),
#  ('INJURY - OTHER', 2015, 4, 6),
#  ('FALSE REPORT', 2015, 3, 6),
#  ('PROPERTY DAMAGE-RESIDENTIAL', 2014, 12, 6),
#  ('DISPUTE-CIVIL PROPERTY (NON AU', 2015, 1, 6),
#  ('WARRANT-FUGITIVE', 2015, 6, 6),
#  ('DUI-LIQUOR', 2015, 4, 6),
#  ('EMBEZZLE', 2014, 12, 5),
#  ('ASSLT-NONAGG-POLICE', 2015, 5, 5),
#  ('NARC-SELL-HEROIN', 2015, 1, 5),
#  ('PROSTITUTION-ASSIST-PROMOTE', 2015, 6, 5),
#  ('BURGLARY-SECURE PARKING-NONRES', 2015, 1, 5),
#  ('FORGERY-CHECK', 2015, 3, 5),
#  ('THEFT-LICENSE PLATE', 2014, 11, 5),
#  ('NARC-EQUIPMENT/PARAPHENALIA', 2015, 2, 5),
#  ('ROBBERY-BUSINESS-WEAPON', 2015, 4, 5),
#  ('DISPUTE-CIVIL PROPERTY (NON AU', 2015, 2, 5),
#  ('WEAPON-DISCHARGE', 2015, 3, 5),
#  ('FORGERY-CHECK', 2015, 5, 5),
#  ('FRAUD-WIRE-ELECTRONIC', 2015, 6, 5),
#  ('NARC-FORGERY-PRESCRIPTION', 2015, 6, 5),
#  ('THEFT-CARPROWL', 2014, 2, 5),
#  ('ROBBERY-BUSINESS-WEAPON', 2015, 6, 5),
#  ('THEFT-BUILDING', 2014, 3, 5),
#  ('NARC-FOUND-HEROIN', 2015, 1, 5),
#  ('FORGERY-CHECK', 2015, 1, 5),
#  ('NARC-FOUND-OTHER', 2015, 4, 5),
#  ('ASSLT-NONAGG-POLICE', 2015, 4, 5),
#  ('INJURY - OTHER', 2015, 5, 5),
#  ('PROPERTY DAMAGE - GRAFFITI', 2014, 12, 5),
#  ('NARC-FOUND-OTHER', 2015, 6, 5),
#  ('DISTURBANCE-NOISE', 2015, 4, 5),
#  ('ANIMAL-OTH', 2015, 2, 5),
#  ('DUI-LIQUOR', 2015, 3, 5),
#  ('THEFT-COINOP', 2015, 1, 5),
#  ('FRAUD-IDENTITY THEFT', 2014, 9, 5),
#  ('THEFT-PRSNATCH', 2015, 6, 5),
#  ('FRAUD-IDENTITY THEFT', 2013, 12, 5),
#  ('NARC-POSSESS-MARIJU', 2015, 3, 5),
#  ('ROBBERY-BUSINESS-WEAPON', 2015, 2, 5),
#  ('ANIMAL-OTH', 2015, 3, 5),
#  ('FRAUD-WIRE-ELECTRONIC', 2015, 5, 5),
#  ('FRAUD-IDENTITY THEFT', 2014, 8, 5),
#  ('PROP RECOVERED-OTHER AGENCY', 2015, 4, 5),
#  ('NARC-EQUIPMENT/PARAPHENALIA', 2015, 5, 5),
#  ('DISPUTE-CIVIL PROPERTY (AUTO)', 2015, 4, 5),
#  ('ROBBERY-BUSINESS-GUN', 2015, 1, 5),
#  ('COUNTERFEIT', 2015, 6, 5),
#  ('FRAUD-IDENTITY THEFT', 2007, 10, 4),
#  ('ILLEGAL DUMPING', 2015, 4, 4),
#  ('ASSLT-AGG-POLICE-WEAPON', 2015, 5, 4),
#  ('THEFT-OTH', 2014, 10, 4),
#  ('RECKLESS BURNING', 2015, 5, 4),
#  ('FRAUD-CHECK', 2014, 10, 4),
#  ('NARC-POSSESS-AMPHETAMINE', 2015, 1, 4),
#  ('NARC-SELL-AMPHETAMINE', 2015, 1, 4),
#  ('DISORDERLY CONDUCT', 2015, 3, 4),
#  ('PROPERTY LOST', 2014, 9, 4),
#  ('DISPUTE-CIVIL PROPERTY (AUTO)', 2015, 5, 4),
#  ('THEFT-BUILDING', 2014, 11, 4),
#  ('THEFT-AUTOACC', 2014, 12, 4),
#  ('NARC-SELL-MARIJU', 2015, 4, 4),
#  ('VEH-THEFT-TRAILER', 2015, 6, 4),
#  ('NARC-SELL-AMPHETAMINE', 2015, 5, 4),
#  ('NARC-FOUND-METH', 2015, 6, 4),
#  ('ROBBERY-RESIDENCE-WEAPON', 2015, 4, 4),
#  ('NARC-EQUIPMENT/PARAPHENALIA', 2015, 6, 4),
#  ('PROP RECOVERED-OTHER AGENCY', 2015, 2, 4),
#  ('ASSLT-NONAGG-POLICE', 2015, 6, 4),
#  ('DRIVE-BY', 2015, 3, 4),
#  ('PROSTITUTION PATRONIZING', 2015, 2, 4),
#  ('THEFT-BUILDING', 2014, 10, 4),
#  ('COUNTERFEIT', 2014, 11, 4),
#  ('ILLEGAL DUMPING', 2015, 6, 4),
#  ('NARC-FOUND-OTHER', 2015, 2, 4),
#  ('MALICIOUS HARASSMENT', 2015, 1, 4),
#  ('THEFT-AUTO PARTS', 2015, 3, 4),
#  ('PROPERTY STOLEN-TRAFFICKING', 2015, 3, 4),
#  ('ASSLT-AGG-POLICE-WEAPON', 2015, 1, 4),
#  ('NARC-FOUND-MARIJU', 2015, 5, 4),
#  ('LIQUOR LAW VIOLATION', 2015, 3, 4),
#  ('NARC-SELL-HEROIN', 2015, 3, 4),
#  ('FRAUD-COMPUTER', 2015, 3, 4),
#  ('ROBBERY-RESIDENCE-BODYFORCE', 2015, 1, 4),
#  ('FRAUD-IDENTITY THEFT', 2014, 2, 4),
#  ('FRAUD-COMPUTER', 2015, 4, 4),
#  ('NARC-SELL-HEROIN', 2015, 4, 4),
#  ('WEAPON-UNLAWFUL USE', 2015, 1, 4),
#  ('FRAUD-OTHER', 2014, 9, 4),
#  ('BURGLARY-FORCE-NONRES', 2014, 11, 4),
#  ('ENDANGERMENT', 2015, 1, 4),
#  ('DUI-LIQUOR', 2015, 6, 4),
#  ('ROBBERY-RESIDENCE-WEAPON', 2015, 5, 4),
#  ('THEFT-CARPROWL', 2014, 4, 4),
#  ('THEFT-AUTO PARTS', 2015, 5, 4),
#  ('ANIMAL-BITE', 2015, 2, 4),
#  ('DISORDERLY CONDUCT', 2015, 5, 4),
#  ('OBSTRUCT', 2015, 6, 4),
#  ('ANIMAL-BITE', 2015, 3, 3),
#  ('VIOL-COURT ORDER', 2014, 12, 3),
#  ('NARC-SELL-MARIJU', 2015, 3, 3),
#  ('NARC-SELL-METH', 2015, 2, 3),
#  ('THEFT-PRSNATCH', 2015, 5, 3),
#  ('WEAPON-UNLAWFUL USE', 2015, 3, 3),
#  ('THEFT-BOAT', 2015, 4, 3),
#  ('PROSTITUTION', 2015, 3, 3),
#  ('VEH-THEFT-TRAILER', 2015, 3, 3),
#  ('INJURY - ACCIDENTAL', 2015, 5, 3),
#  ('EMBEZZLE', 2014, 4, 3),
#  ('INJURY - OTHER', 2015, 2, 3),
#  ('PROSTITUTION LOITERING', 2015, 1, 3),
#  ('ROBBERY-BANK-BODYFORCE', 2015, 1, 3),
#  ('NARC-DRUG TRAFFIC LOITERING', 2015, 2, 3),
#  ('LIQUOR LAW VIOLATION', 2015, 4, 3),
#  ('THEFT-AUTO PARTS', 2015, 2, 3),
#  ('WEAPON-UNLAWFUL USE', 2015, 4, 3),
#  ('FORGERY-CREDIT CARD', 2015, 3, 3),
#  ('ELUDING-FELONY FLIGHT', 2015, 6, 3),
#  ('FORGERY-OTH', 2015, 4, 3),
#  ('FRAUD-IDENTITY THEFT', 2014, 3, 3),
#  ('PORNOGRAPHY-OBSCENE MATERIAL', 2015, 3, 3),
#  ('BURGLARY-NOFORCE-NONRES', 2014, 12, 3),
#  ('PROPERTY STOLEN-TRAFFICKING', 2015, 2, 3),
#  ('WEAPON-UNLAWFUL USE', 2015, 6, 3),
#  ('ENDANGERMENT', 2015, 5, 3),
#  ('DRIVE-BY', 2015, 6, 3),
#  ('THEFT-AUTO PARTS', 2015, 4, 3),
#  ('ROBBERY-RESIDENCE-BODYFORCE', 2015, 5, 3),
#  ('NARC-FRAUD-PRESCRIPTION', 2015, 6, 3),
#  ('NARC-FOUND-HEROIN', 2015, 3, 3),
#  ('NARC-DRUG TRAFFIC LOITERING', 2015, 4, 3),
#  ('FORGERY-CHECK', 2014, 10, 3),
#  ('FORGERY-OTH', 2015, 3, 3),
#  ('EXTORTION', 2015, 5, 3),
#  ('PROP RECOVERED-OTHER AGENCY', 2015, 3, 3),
#  ('ANIMAL-OTH', 2015, 4, 3),
#  ('THEFT-BUILDING', 2014, 6, 3),
#  ('DISORDERLY CONDUCT', 2015, 4, 3),
#  ('THEFT-MAIL', 2014, 11, 3),
#  ('NARC-FOUND-MARIJU', 2015, 3, 3),
#  ('ELUDING-FELONY FLIGHT', 2015, 3, 3),
#  ('WARRANT-FUGITIVE', 2015, 5, 3),
#  ('ANIMAL-BITE', 2015, 4, 3),
#  ('NARC-FOUND-MARIJU', 2015, 2, 3),
#  ('ROBBERY-RESIDENCE-WEAPON', 2015, 2, 3),
#  ('NARC-FOUND-HEROIN', 2015, 4, 3),
#  ('ASSLT-AGG-POLICE-WEAPON', 2015, 3, 3),
#  ('DISPUTE-CIVIL PROPERTY (AUTO)', 2015, 3, 3),
#  ('ILLEGAL DUMPING', 2015, 5, 3),
#  ('ROBBERY-RESIDENCE-GUN', 2015, 5, 3),
#  ('INJURY - OTHER', 2015, 1, 3),
#  ('THEFT-SHOPLIFT', 2014, 12, 3),
#  ('FORGERY-CHECK', 2015, 6, 3),
#  ('PROPERTY LOST - POLICE EQUIPME', 2015, 4, 3),
#  ('ANIMAL-CRUELTY', 2015, 6, 3),
#  ('WEAPON-SURRENDER-EXCLUDING FIR', 2015, 6, 3),
#  ('ELUDING-FELONY FLIGHT', 2015, 1, 3),
#  ('INJURY - ACCIDENTAL', 2015, 4, 3),
#  ('BIAS INCIDENT', 2015, 5, 3),
#  ('NARC-DRUG TRAFFIC LOITERING', 2015, 5, 3),
#  ('BURGLARY-NOFORCE-RES', 2014, 11, 3),
#  ('THEFT-BOAT', 2015, 5, 3),
#  ('THEFT-PRSNATCH', 2015, 1, 3),
#  ('NARC-SELL-METH', 2015, 6, 3),
#  ('NARC-FORGERY-PRESCRIPTION', 2015, 2, 3),
#  ('RECKLESS BURNING', 2015, 6, 3),
#  ('NARC-FOUND-MARIJU', 2015, 6, 3),
#  ('VEH-THEFT-TRAILER', 2015, 4, 3),
#  ('FRAUD-COMPUTER', 2015, 5, 3),
#  ('FRAUD-IDENTITY THEFT', 2012, 12, 3),
#  ('NARC-DRUG TRAFFIC LOITERING', 2015, 3, 3),
#  ('FRAUD-IDENTITY THEFT', 2014, 7, 3),
#  ('WEAPON-SURRENDER-EXCLUDING FIR', 2015, 5, 3),
#  ('NARC-POSSESS-OTHER', 2015, 3, 3),
#  ('NARC-FOUND-OTHER', 2015, 5, 3),
#  ('WEAPON-DISCHARGE', 2015, 6, 3),
#  ('BURGLARY-NOFORCE-RES', 2014, 9, 3),
#  ('DRIVE-BY', 2015, 4, 3),
#  ('THEFT-OTH', 2014, 9, 3),
#  ('WARRANT-FUGITIVE', 2015, 4, 3),
#  ('NARC-POSSESS-PILL/TABLET', 2015, 1, 2),
#  ('INJURY - ACCIDENTAL', 2015, 1, 2),
#  ('ASSLT-NONAGG', 2014, 12, 2),
#  ('VEH-THEFT-AUTO', 2014, 11, 2),
#  ('BURGLARY-FORCE-RES', 2014, 6, 2),
#  ('FORGERY-CHECK', 2014, 11, 2),
#  ('NARC-PRODUCE-MARIJU', 2015, 3, 2),
#  ('FRAUD-CREDIT CARD', 2014, 8, 2),
#  ('FORGERY-CREDIT CARD', 2015, 5, 2),
#  ('ASSLT-AGG-POLICE-WEAPON', 2015, 2, 2),
#  ('NARC-FOUND-HEROIN', 2015, 5, 2),
#  ('BURGLARY-NOFORCE-RES', 2014, 6, 2),
#  ('LIQUOR LAW VIOLATION', 2015, 2, 2),
#  ('NARC-SELL-HEROIN', 2015, 2, 2),
#  ('VEH-THEFT-TRAILER', 2015, 5, 2),
#  ('WEAPON-UNLAWFUL USE', 2015, 2, 2),
#  ('FRAUD-CREDIT CARD', 2014, 10, 2),
#  ('NARC-FOUND-METH', 2015, 5, 2),
#  ('[INC - CASE DC USE ONLY]', 2015, 3, 2),
#  ('NARC-SELL-METH', 2015, 3, 2),
#  ('HARASSMENT', 2014, 4, 2),
#  ('FRAUD-OTHER', 2014, 11, 2),
#  ('VEH-THEFT-TRAILER', 2014, 12, 2),
#  ('PROPERTY STOLEN-TRAFFICKING', 2015, 4, 2),
#  ('EXTORTION', 2015, 3, 2),
#  ('ASSLT-AGG-POLICE-BODYFORCE', 2015, 2, 2),
#  ('ASSLT-NONAGG', 2014, 1, 2),
#  ('FRAUD-IDENTITY THEFT', 2013, 6, 2),
#  ('HOMICIDE-PREMEDITATED-GUN', 2015, 3, 2),
#  ('FORGERY-OTH', 2015, 2, 2),
#  ('NARC-POSSESS-METH', 2015, 5, 2),
#  ('THEFT-CARPROWL', 2014, 8, 2),
#  ('NARC-POSSESS-MARIJU', 2015, 2, 2),
#  ('FIREWORK-USE', 2015, 2, 2),
#  ('HARASSMENT', 2014, 10, 2),
#  ('VEH-THEFT-TRUCK', 2014, 12, 2),
#  ('FRAUD-IDENTITY THEFT', 2010, 5, 2),
#  ('ILLEGAL DUMPING', 2015, 1, 2),
#  ('HARASSMENT', 2013, 8, 2),
#  ('FRAUD-IDENTITY THEFT', 2012, 7, 2),
#  ('NARC-SELL-MARIJU', 2015, 1, 2),
#  ('FRAUD-CHECK', 2014, 7, 2),
#  ('PROSTITUTION LOITERING', 2015, 4, 2),
#  ('NARC-FORGERY-PRESCRIPTION', 2015, 5, 2),
#  ('MALICIOUS HARASSMENT', 2015, 6, 2),
#  ('FRAUD-CREDIT CARD', 2014, 2, 2),
#  ('BURGLARY-SECURE PARKING-RES', 2014, 11, 2),
#  ('VEH-THEFT-MTRCYCLE', 2014, 12, 2),
#  ('NARC-FOUND-COCAINE', 2015, 4, 2),
#  ('PROPERTY LOST - POLICE EQUIPME', 2015, 3, 2),
#  ('THEFT-COINOP', 2015, 2, 2),
#  ('NARC-FOUND-COCAINE', 2015, 3, 2),
#  ('NARC-FOUND-PILL/TABLET', 2015, 5, 2),
#  ('URINATING/DEFECATING-IN PUBLIC', 2014, 3, 2),
#  ('ROBBERY-RESIDENCE-GUN', 2015, 4, 2),
#  ('NARC-POSSESS-PRESCRIPTION', 2015, 1, 2),
#  ('NARC-DRUG TRAFFIC LOITERING', 2015, 1, 2),
#  ('ASSLT-AGG-POLICE-BODYFORCE', 2015, 1, 2),
#  ('NARC-FOUND-METH', 2015, 4, 2),
#  ('FORGERY-CREDIT CARD', 2015, 2, 2),
#  ('THEFT-COINOP', 2015, 6, 2),
#  ('INJURY - ACCIDENTAL', 2015, 3, 2),
#  ('THEFT-OTH', 2014, 1, 2),
#  ('THEFT-CARPROWL', 2014, 9, 2),
#  ('NARC-POSSESS-HEROIN', 2014, 4, 2),
#  ('ENDANGERMENT', 2015, 4, 2),
#  ('ROBBERY-RESIDENCE-BODYFORCE', 2015, 2, 2),
#  ('FRAUD-IDENTITY THEFT', 2012, 1, 2),
#  ('THEFT-BICYCLE', 2014, 1, 2),
#  ('[INC - CASE DC USE ONLY]', 2015, 5, 2),
#  ('THEFT-OTH', 2013, 1, 2),
#  ('ROBBERY-RESIDENCE-BODYFORCE', 2015, 4, 2),
#  ('NARC-POSSESS-AMPHETAMINE', 2015, 5, 2),
#  ('ASSLT-AGG-POLICE-BODYFORCE', 2015, 5, 2),
#  ('WEAPON-CONCEALED', 2015, 3, 2),
#  ('HOMICIDE-PREMEDITATED-WEAPON', 2015, 3, 2),
#  ('NARC-EQUIPMENT/PARAPHENALIA', 2015, 1, 2),
#  ('FORGERY-CREDIT CARD', 2015, 4, 2),
#  ('NARC-FOUND-METH', 2015, 2, 2),
#  ('THEFT-OTH', 2014, 5, 2),
#  ('MALICIOUS HARASSMENT', 2015, 3, 2),
#  ('THEFT-BUILDING', 2014, 1, 2),
#  ('VEH-THEFT-TRAILER', 2015, 2, 2),
#  ('[INC - CASE DC USE ONLY]', 2015, 1, 2),
#  ('NARC-FOUND-AMPHETAMINE', 2015, 1, 2),
#  ('PROPERTY STOLEN-SELL', 2015, 4, 2),
#  ('BURGLARY-NOFORCE-RES', 2014, 10, 2),
#  ('PROPERTY LOST - POLICE EQUIPME', 2015, 6, 2),
#  ('NARC-FOUND-COCAINE', 2015, 5, 2),
#  ('NARC-FRAUD-PRESCRIPTION', 2015, 1, 2),
#  ('NARC-SELL-OTHER', 2015, 5, 2),
#  ('WARRANT-FUGITIVE', 2015, 3, 2),
#  ('FRAUD-OTHER', 2013, 10, 2),
#  ('ILLEGAL DUMPING', 2015, 3, 2),
#  ('PROPERTY LOST - POLICE EQUIPME', 2015, 5, 2),
#  ('ESCAPE', 2015, 1, 2),
#  ('PROPERTY LOST - POLICE EQUIPME', 2014, 12, 2),
#  ('FRAUD-CREDIT CARD', 2014, 9, 2),
#  ('NARC-POSSESS-OTHER', 2015, 1, 2),
#  ('ELUDING-FELONY FLIGHT', 2015, 2, 2),
#  ('DUI-LIQUOR', 2015, 2, 2),
#  ('PROPERTY LOST - POLICE EQUIPME', 2015, 1, 2),
#  ('EMBEZZLE', 2013, 6, 2),
#  ('FRAUD-IDENTITY THEFT', 2013, 3, 2),
#  ('INJURY - OTHER', 2015, 3, 2),
#  ('ANIMAL-CRUELTY', 2015, 4, 2),
#  ('ILLEGAL DUMPING', 2015, 2, 2),
#  ('WEAPON-SURRENDER-EXCLUDING FIR', 2015, 4, 2),
#  ('NARC-FORGERY-PRESCRIPTION', 2015, 3, 2),
#  ('URINATING/DEFECATING-IN PUBLIC', 2015, 1, 2),
#  ('BURGLARY-SECURE PARKING-RES', 2011, 1, 2),
#  ('RECKLESS BURNING', 2015, 2, 2),
#  ('ASSLT-AGG-POLICE-WEAPON', 2015, 6, 2),
#  ('DISPUTE-CIVIL PROPERTY (AUTO)', 2015, 2, 2),
#  ('HOMICIDE-PREMEDITATED-BODYFORC', 2015, 2, 2),
#  ('THEFT-MAIL', 2014, 1, 2),
#  ('NARC-POSSESS-MARIJU', 2015, 1, 2),
#  ('PROSTITUTION LOITERING', 2015, 5, 2),
#  ('FRAUD-COMPUTER', 2015, 6, 2),
#  ('ROBBERY-BANK-GUN', 2015, 3, 1),
#  ('THEFT-BUILDING', 2014, 5, 1),
#  ('THEFT-LICENSE PLATE', 2013, 4, 1),
#  ('PROPERTY LOST', 2013, 5, 1),
#  ('FRAUD-CHECK', 2014, 9, 1),
#  ('NARC-FOUND-MARIJU', 2015, 1, 1),
#  ('FRAUD-IDENTITY THEFT', 2012, 9, 1),
#  ('ENDANGERMENT', 2015, 3, 1),
#  ('THEFT-BICYCLE', 2013, 11, 1),
#  ('COUNTERFEIT', 2014, 6, 1),
#  ('PROPERTY RECOVERED - POLICE EQ', 2015, 5, 1),
#  ('PROPERTY FOUND', 2014, 11, 1),
#  ('FRAUD-IDENTITY THEFT', 2008, 9, 1),
#  ('BURGLARY-NOFORCE-RES', 2014, 4, 1),
#  ('EXTORTION', 2015, 2, 1),
#  ('HOMICIDE-PREMEDITATED-GUN', 2015, 6, 1),
#  ('WEAPON-CONCEALED', 2015, 2, 1),
#  ('PROPERTY LOST', 2014, 4, 1),
#  ('FRAUD-IDENTITY THEFT', 2008, 1, 1),
#  ('DISPUTE-CIVIL PROPERTY (NON AU', 2014, 11, 1),
#  ('FRAUD-CHECK', 2014, 1, 1),
#  ('FRAUD-OTHER', 2014, 7, 1),
#  ('HARASSMENT', 2008, 4, 1),
#  ('THEFT-CARPROWL', 2014, 1, 1),
#  ('EMBEZZLE', 2012, 7, 1),
#  ('HARASSMENT', 2014, 11, 1),
#  ('ASSLT-NONAGG', 2014, 10, 1),
#  ('PROPERTY LOST', 2012, 7, 1),
#  ('THEFT-AUTO PARTS', 2014, 12, 1),
#  ('NARC-MANUFACTURE-OTHER', 2015, 1, 1),
#  ('ROBBERY-RESIDENCE-WEAPON', 2015, 6, 1),
#  ('HARASSMENT', 2010, 1, 1),
#  ('EMBEZZLE', 2013, 12, 1),
#  ('BIAS INCIDENT', 2015, 2, 1),
#  ('FRAUD-OTHER', 2014, 3, 1),
#  ('NARC-FOUND-METH', 2015, 3, 1),
#  ('FRAUD-IDENTITY THEFT', 2014, 6, 1),
#  ('FRAUD-OTHER', 2014, 1, 1),
#  ('EMBEZZLE', 2014, 9, 1),
#  ('MALICIOUS HARASSMENT', 2015, 2, 1),
#  ('FRAUD-CHECK', 2012, 5, 1),
#  ('FORGERY-CHECK', 2014, 7, 1),
#  ('BIAS INCIDENT', 2015, 1, 1),
#  ('FRAUD-IDENTITY THEFT', 2002, 1, 1),
#  ('ROBBERY-RESIDENCE-BODYFORCE', 2015, 6, 1),
#  ('NARC-FRAUD-PRESCRIPTION', 2015, 2, 1),
#  ('HARASSMENT', 2014, 7, 1),
#  ('FRAUD-IDENTITY THEFT', 2011, 4, 1),
#  ('DUI-LIQUOR', 2015, 5, 1),
#  ('WEAPON-SURRENDER-EXCLUDING FIR', 2015, 1, 1),
#  ('FRAUD-CHECK', 2014, 6, 1),
#  ('EMBEZZLE', 2008, 6, 1),
#  ('RECKLESS BURNING', 2015, 4, 1),
#  ('NARC-SELL-MARIJU', 2015, 5, 1),
#  ('URINATING/DEFECATING-IN PUBLIC', 2015, 4, 1),
#  ('FALSE REPORT', 2014, 12, 1),
#  ('FORGERY-OTH', 2014, 12, 1),
#  ('FIREWORK-USE', 2015, 4, 1),
#  ('WEAPON-CONCEALED', 2015, 6, 1),
#  ('FRAUD-IDENTITY THEFT', 2011, 3, 1),
#  ('DRIVE-BY', 2015, 2, 1),
#  ('FORGERY-OTH', 2014, 4, 1),
#  ('THEFT-LICENSE PLATE', 2014, 6, 1),
#  ('THEFT-BUILDING', 2014, 7, 1),
#  ('ROBBERY-BUSINESS-GUN', 2015, 6, 1),
#  ('PROPERTY LOST - POLICE EQUIPME', 2014, 4, 1),
#  ('BURGLARY-FORCE-RES', 2014, 11, 1),
#  ('BIAS INCIDENT', 2015, 4, 1),
#  ('THEFT-OTH', 2012, 11, 1),
#  ('BURGLARY-NOFORCE-RES', 2012, 6, 1),
#  ('METRO TRANSIT - ON BUS, TUNNEL', 2015, 4, 1),
#  ('NARC-FORGERY-PRESCRIPTION', 2015, 4, 1),
#  ('PROSTITUTION LOITERING', 2015, 2, 1),
#  ('FRAUD-OTHER', 2013, 6, 1),
#  ('FRAUD-CREDIT CARD', 2014, 5, 1),
#  ('FRAUD-CHECK', 2010, 7, 1),
#  ('ROBBERY-RESIDENCE-WEAPON', 2015, 3, 1),
#  ('ROBBERY-RESIDENCE-WEAPON', 2015, 1, 1),
#  ('EMBEZZLE', 2014, 6, 1),
#  ('NARC-POSSESS-OTHER', 2015, 4, 1),
#  ('ASSLT-AGG-WEAPON', 2014, 12, 1),
#  ('THEFT-BOAT', 2014, 9, 1),
#  ('THEFT-CARPROWL', 2014, 7, 1),
#  ('THEFT-AUTOACC', 2014, 11, 1),
#  ('PROPERTY LOST', 2014, 8, 1),
#  ('INJURY - ACCIDENTAL', 2015, 6, 1),
#  ('THEFT-OTH', 2013, 10, 1),
#  ('THEFT-PKPOCKET', 2014, 9, 1),
#  ('FRAUD-IDENTITY THEFT', 2010, 11, 1),
#  ('THREATS-OTHER', 2014, 3, 1),
#  ('NARC-FOUND-PILL/TABLET', 2015, 1, 1),
#  ('DISORDERLY CONDUCT', 2015, 2, 1),
#  ('PROPERTY LOST', 2014, 6, 1),
#  ('PROSTITUTION LOITERING', 2015, 3, 1),
#  ('NARC-SELL-AMPHETAMINE', 2015, 2, 1),
#  ('FORGERY-CHECK', 2005, 3, 1),
#  ('ROBBERY-BANK-GUN', 2015, 6, 1),
#  ('PROPERTY LOST', 2001, 8, 1),
#  ('NARC-POSSESS-AMPHETAMINE', 2015, 6, 1),
#  ('FRAUD-IDENTITY THEFT', 2011, 10, 1),
#  ('THEFT-LICENSE PLATE', 2010, 6, 1),
#  ('FRAUD-IDENTITY THEFT', 2004, 7, 1),
#  ('HOMICIDE-PREMEDITATED-GUN', 2015, 4, 1),
#  ('HARASSMENT', 1990, 5, 1),
#  ('BURGLARY-NOFORCE-NONRES', 2014, 11, 1),
#  ('URINATING/DEFECATING-IN PUBLIC', 2015, 2, 1),
#  ('PROSTITUTION-ASSIST-PROMOTE', 2015, 2, 1),
#  ('[INC - CASE DC USE ONLY]', 2015, 2, 1),
#  ('NARC-MANUFACTURE-OTHER', 2015, 3, 1),
#  ('ASSLT-AGG-POLICE-BODYFORCE', 2015, 6, 1),
#  ('NARC-POSSESS-PILL/TABLET', 2015, 5, 1),
#  ('FRAUD-CHECK', 2000, 1, 1),
#  ('PROSTITUTION-ASSIST-PROMOTE', 2014, 2, 1),
#  ('FRAUD-OTHER', 2012, 4, 1),
#  ('DISPUTE-CIVIL PROPERTY (AUTO)', 2015, 1, 1),
#  ('THEFT-OTH', 2005, 6, 1),
#  ('HARASSMENT', 2014, 3, 1),
#  ('LOITERING', 2015, 2, 1),
#  ('FRAUD-OTHER', 2012, 10, 1),
#  ('NARC-DRUG TRAFFIC LOITERING', 2015, 6, 1),
#  ('THEFT-LICENSE PLATE', 2013, 5, 1),
#  ('FRAUD-IDENTITY THEFT', 2013, 2, 1),
#  ('[INC - CASE DC USE ONLY]', 2015, 4, 1),
#  ('NARC-POSSESS-MARIJU', 2015, 5, 1),
#  ('NARC-FOUND-PILL/TABLET', 2015, 3, 1),
#  ('PROPERTY DAMAGE-RESIDENTIAL', 2014, 11, 1),
#  ('NARC-FOUND-AMPHETAMINE', 2015, 4, 1),
#  ('NARC-POSSESS-AMPHETAMINE', 2015, 2, 1),
#  ('FRAUD-IDENTITY THEFT', 2007, 4, 1),
#  ('FRAUD-CREDIT CARD', 2013, 8, 1),
#  ('THEFT-BUILDING', 2013, 2, 1),
#  ('FRAUD-IDENTITY THEFT', 2009, 9, 1),
#  ('FRAUD-IDENTITY THEFT', 2011, 7, 1),
#  ('VEH-THEFT-AUTO', 2014, 8, 1),
#  ('THREATS-OTHER', 2010, 1, 1),
#  ('THEFT-LICENSE PLATE', 2014, 7, 1),
#  ('FRAUD-OTHER', 2009, 4, 1),
#  ('GAMBLE-BETTING', 2015, 5, 1),
#  ('NARC-FRAUD-PRESCRIPTION', 2015, 5, 1),
#  ('EXTORTION', 2015, 4, 1),
#  ('VEH-THEFT-TRAILER', 2014, 11, 1),
#  ('EMBEZZLE', 2011, 5, 1),
#  ('WARRARR-FELONY', 2014, 12, 1),
#  ('PROPERTY DAMAGE - GRAFFITI', 2014, 1, 1),
#  ('PROPERTY STOLEN-POSSESS', 2014, 12, 1),
#  ('EMBEZZLE', 2014, 3, 1),
#  ('THEFT-OTH', 2014, 2, 1),
#  ('NARC-FOUND-SYNTHETIC', 2015, 4, 1),
#  ('BURGLARY-NOFORCE-NONRES', 2014, 7, 1),
#  ('FRAUD-OTHER', 2014, 5, 1),
#  ('DISTURBANCE-OTH', 2013, 1, 1),
#  ('THEFT-MAIL', 2014, 8, 1),
#  ('NARC-FOUND-AMPHETAMINE', 2015, 6, 1),
#  ('FRAUD-WELFARE', 2015, 5, 1),
#  ('THEFT-MAIL', 2014, 10, 1),
#  ('NARC-FOUND-PILL/TABLET', 2015, 2, 1),
#  ('DISTURBANCE-OTH', 2014, 12, 1),
#  ('BIAS INCIDENT', 2015, 6, 1),
#  ('ROBBERY-BANK-BODYFORCE', 2015, 6, 1),
#  ('PROPERTY DAMAGE-NON RESIDENTIA', 2014, 6, 1),
#  ('DISORDERLY CONDUCT', 2015, 1, 1),
#  ('FRAUD-IDENTITY THEFT', 1999, 1, 1),
#  ('DRIVE-BY', 2015, 5, 1),
#  ('THEFT-LICENSE PLATE', 2014, 9, 1),
#  ('BURGLARY-NOFORCE-NONRES', 2014, 10, 1),
#  ('FRAUD-OTHER', 2013, 8, 1),
#  ('DISTURBANCE-OTH', 2014, 1, 1),
#  ('THEFT-CARPROWL', 2014, 3, 1),
#  ('FORGERY-CREDIT CARD', 2014, 12, 1),
#  ('FRAUD-IDENTITY THEFT', 2006, 1, 1),
#  ('EXTORTION', 2015, 6, 1),
#  ('THREATS-WEAPON', 2014, 11, 1),
#  ('PORNOGRAPHY-OBSCENE MATERIAL', 2015, 1, 1),
#  ('FRAUD-IDENTITY THEFT', 2010, 4, 1),
#  ('THEFT-OTH', 2014, 3, 1),
#  ('PROPERTY STOLEN-SELL', 2015, 5, 1),
#  ('BURGLARY-FORCE-NONRES', 2013, 3, 1),
#  ('THEFT-BICYCLE', 2014, 4, 1),
#  ('FRAUD-OTHER', 2014, 10, 1),
#  ('DISPUTE-CIVIL PROPERTY (AUTO)', 2015, 6, 1),
#  ('LIQUOR LAW VIOLATION', 2015, 6, 1),
#  ('FRAUD-IDENTITY THEFT', 2012, 4, 1),
#  ('FRAUD-IDENTITY THEFT', 2001, 6, 1),
#  ('WEAPON-SURRENDER-EXCLUDING FIR', 2015, 3, 1),
#  ('DUI-DRUGS', 2015, 1, 1),
#  ('FRAUD-CHECK', 2014, 4, 1),
#  ('FALSE REPORT', 2015, 2, 1),
#  ('VEH-THEFT-AUTO', 2014, 5, 1),
#  ('THEFT-BICYCLE', 2014, 3, 1),
#  ('FRAUD-OTHER', 2010, 5, 1),
#  ('NARC-FOUND-METH', 2015, 1, 1),
#  ('PROPERTY LOST', 2014, 11, 1),
#  ('HARASSMENT', 2014, 1, 1),
#  ('FRAUD-IDENTITY THEFT', 2013, 8, 1),
#  ('EMBEZZLE', 2010, 1, 1),
#  ('FRAUD-OTHER', 2014, 2, 1),
#  ('VEH-THEFT-AUTO', 2014, 4, 1),
#  ('THEFT-CARPROWL', 2014, 5, 1),
#  ('THEFT-LICENSE PLATE', 2014, 4, 1),
#  ('EMBEZZLE', 2005, 8, 1),
#  ('THEFT-AUTOACC', 2014, 7, 1),
#  ('PROPERTY LOST', 2014, 5, 1),
#  ('NARC-POSSESS-PRESCRIPTION', 2015, 3, 1),
#  ('DUI-DRUGS', 2015, 2, 1),
#  ('NARC-FOUND-HALLUCINOGEN', 2015, 1, 1),
#  ('EMBEZZLE', 2014, 11, 1),
#  ('ROBBERY-RESIDENCE-BODYFORCE', 2015, 3, 1),
#  ('URINATING/DEFECATING-IN PUBLIC', 2015, 6, 1),
#  ('THEFT-MAIL', 2014, 6, 1),
#  ('LOITERING', 2015, 4, 1),
#  ('ROBBERY-BUSINESS-GUN', 2015, 5, 1),
#  ('NARC-POSSESS-MARIJU', 2015, 6, 1),
#  ('NARC-FOUND-COCAINE', 2015, 6, 1),
#  ('BIAS INCIDENT', 2015, 3, 1),
#  ('FRAUD-IDENTITY THEFT', 2011, 6, 1),
#  ('NARC-POSSESS-PILL/TABLET', 2015, 6, 1),
#  ('NARC-SELL-MARIJU', 2015, 6, 1),
#  ('THEFT-LICENSE PLATE', 2014, 3, 1),
#  ('THEFT-BICYCLE', 2014, 11, 1),
#  ('PROPERTY LOST', 2013, 1, 1),
#  ('TRAFFIC', 2014, 11, 1),
#  ('THEFT OF SERVICES', 2013, 4, 1),
#  ('FRAUD-IDENTITY THEFT', 2012, 11, 1),
#  ('ANIMAL-CRUELTY', 2015, 3, 1),
#  ('BURGLARY-SECURE PARKING-RES', 2014, 10, 1),
#  ('NARC-SELL-METH', 2015, 5, 1),
#  ('MALICIOUS HARASSMENT', 2015, 4, 1),
#  ('HOMICIDE-NEG-MANS-BODYFORCE', 2015, 6, 1),
#  ('THEFT-COINOP', 2015, 5, 1),
#  ('PROPERTY FOUND', 2014, 9, 1),
#  ('FRAUD-IDENTITY THEFT', 2013, 10, 1),
#  ('THEFT-OTH', 2013, 11, 1)]

# %% [markdown]
# ## EXERCISE 2: 20-30 MINUTES

# %% [markdown]
# #### Exercise 2 Debrief:
#
# * what did you learn?

# %% [markdown]
# ### Recall our final analysis question:
#
# * "What is the most common crime within 5 km of my house?"

# %% [markdown]
# #### To answer this we'll need to understand something about mapping, and how databases encode spatial information.

# %% [markdown]
# ### Note that the database currently has latitude and longitude information:

# %%
# %sql SELECT "Latitude", "Longitude" FROM seattlecrimeincidents WHERE gid < 5;
# Out:
# 4 rows affected.
# [(47.6158384, -122.3181689),
#  (47.60087709, -122.3312162),
#  (47.59582098, -122.3175691),
#  (47.6140991, -122.3174884)]

# %% [markdown]
# <br><br>
# <img src="images/earthLatLong.png" width = "800">
# <br><br><br><br>
# [source](https://coast.noaa.gov/digitalcoast/training/datums)

# %%
# %%sql
# SELECT column_name, data_type
# FROM information_schema.columns
# WHERE table_name = 'seattlecrimeincidents' AND (column_name = 'Latitude' OR column_name = 'Longitude');
# Out:
# 2 rows affected.
# [('Longitude', 'double precision'), ('Latitude', 'double precision')]

# %% [markdown]
# <img src="http://neon-workwithdata.github.io/NEON-R-Spatio-Temporal-Data-and-Management-Intro/images/dc-spatial-vector/pnt_line_poly.png" width = "500">

# %% [markdown]
# http://neon-workwithdata.github.io/NEON-R-Spatio-Temporal-Data-and-Management-Intro/
